# %%
# import libraries to navigate within directories
import os
import sys
import re

# the usual suspects
import pandas as pd
import numpy as np
import math
from collections import Counter, defaultdict

# Import sparse to help process NL data into chunks
from scipy import sparse # if we don't use this your computer's memory will see heaven

# NLP libraries
import nltk
## LLR calculation import
from scipy.stats import chi2_contingency
## TF-IDF calculation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import normalize # normalize TF/TF-IDF scores

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Jupyter-specific imports
from IPython.display import clear_output
# %matplotlib inline 

# Suppress warnings (optional)
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
df_metadata_transcript = pd.read_csv('clean_metadata_transcript.csv')
df_metadata_transcript.head(5)
# Out:
#        channel_name                                        video_title  \
# 0  Black Girls Code  Have You Ever Thought About Working at Google?...
# 1  Black Girls Code  Tutorial 4: How to Code Animated Art In JavaSc...
# 2  Black Girls Code                             CODE Along: Win $2500!
# 3  Black Girls Code  Don't Know What Career to Choose? Actress and ...
# 4  Black Girls Code  Watch Actress Ella Balinska Recap Her Career i...
#
#                                      video_url publish_date video_length  \
# 0  https://www.youtube.com/watch?v=ahQQpYG0Lhk      4/26/24         6:26
# 1  https://www.youtube.com/watch?v=I49CXUIXvM8      4/28/23        11:18
# 2  https://www.youtube.com/watch?v=fZKyNSH2mmM      8/25/23         2:19
# 3  https://www.youtube.com/watch?v=ohceCkLK8Wo      8/21/23         0:44
# 4  https://www.youtube.com/watch?v=jAYK6vJbhxU      8/19/23         0:48
#
#     views  likes  comments                                transcript_filename  \
# 0  199330   5625         4  haveyoueverthoughtaboutworkingatgoogleepisode8...
# 1   84000    179         8  tutorial4howtocodeanimatedartinjavascriptcodea...
# 2  139194    344        18                               codealongwin2500.txt
# 3    1143     40         2  dontknowwhatcareertochooseactressandgamerellab...
# 4    3493    117        10  watchactressellabalinskarecaphercareerin60seco...
#
#    Tier (1, 2, or 3)                                            content  \
# 0                  1  hello everyone and welcome back to codal along...
# 1                  1  what's up for the encoders welcome back to the...
# 2                  1  hey what's up everyone I'm Cheyenne and I'm yo...
# 3                  1  this question means so much to me because when...
# 4                  1  60 seconds okay so I started off uh with a cou...
#
#                                 preprocessed_content  total_words  \
# 0  ['hello', 'everyone', 'welcome', 'back', 'coda...          546
# 1  ['whats', 'encoders', 'welcome', 'back', 'four...          711
# 2  ['hey', 'whats', 'everyone', 'im', 'cheyenne',...          209
# 3  ['question', 'mean', 'much', 'whenever', 'anyt...           61
# 4  ['second', 'started', 'couple', 'writer', 'pas...           64
#
#    unique_words
# 0           281
# 1           271
# 2           152
# 3            53
# 4            56

# %% [markdown]
# # Log-Odds Ratio vs. TFDs Visualization per YouTube Channel
# [DEF]: Statistical measure that compares the probability of a word occurring in one corpus versus another, expressed as a logarithmic ratio. It helps identify words that are disproportionately used in one channel compared to others. It's... Step 1: Calculate the Odds for Each Corpus
# For Corpus 1: Take the probability of a word occurring (p1) divided by the probability of it not occurring (1-p1)
# For Corpus 2: Take the probability of a word occurring (p2) divided by the probability of it not occurring (1-p2)
# Step 2: Create the Ratio
# Divide the odds from Corpus 1 by the odds from Corpus 2
# Step 3: Take the Logarithm
# Apply the natural logarithm to this ratio
#
# * In the context of our data, it would help:
#     * Compare word usage patterns between different YouTube channels
#     * Identify characteristic vocabulary unique to specific channels
#     * Measure the relative frequency of terms between different corpora
#     * Visualize word distribution patterns across channels
# * How does this differ from LLR and other metrics?
#     * Uses probability ratios instead of statistical significance testing
#     * Provides a more straightforward interpretation of word frequency differences
#     * Can be combined with Term Frequency Distribution (TFD) for richer analysis
#     * Better for quick comparative analysis without assuming statistical significance
# * Interpretation:
#     * Positive log-odds indicate words more characteristic of the target channel
#     * Negative log-odds show words underrepresented in the target channel
#     * The magnitude indicates the strength of the association
#     * Can be visualized against TFD for better understanding of word importance1
# * Implementation:
#     * Requires calculating word frequencies in both corpora. Applies smoothing to handle zero frequencies. Uses numpy for logarithmic calculations. Can be visualized using scatter plots of log-odds vs TFD

# %%
def calculate_log_odds_vs_tfd(df):
    output_dir = 'Log_Odds_Analysis'
    os.makedirs(output_dir, exist_ok=True)
    
    def calculate_channel_stats(channel_docs, all_docs):
        # Convert string representations of lists to actual lists if needed
        def convert_to_list(doc):
            if isinstance(doc, str):
                # Remove brackets and split on commas
                doc = doc.strip('[]').replace("'", "").split(', ')
            return [word for word in doc if word]
        
        # Convert and filter documents
        channel_docs = [convert_to_list(doc) for doc in channel_docs if doc is not None]
        all_docs = [convert_to_list(doc) for doc in all_docs if doc is not None]
        
        if not channel_docs:
            raise ValueError("No valid documents found in channel")
        
        # Flatten the tokens for frequency counting
        channel_tokens = [token for doc in channel_docs for token in doc]
        all_tokens = [token for doc in all_docs for token in doc]
        
        # Calculate frequencies
        channel_freq = Counter(channel_tokens)
        corpus_freq = Counter(all_tokens)
        
        # Calculate total words
        channel_total = sum(channel_freq.values())
        corpus_total = sum(corpus_freq.values())
        
        # Calculate log odds and TFD
        log_odds_tfd = {}
        for word in channel_freq:
            p1 = (channel_freq[word] + 0.5) / (channel_total + 1)
            p2 = ((corpus_freq[word] - channel_freq[word] + 0.5) / 
                (corpus_total - channel_total + 1))
            
            log_odds = np.log(p1/p2)
            tfd = channel_freq[word] / channel_total
            
            log_odds_tfd[word] = {'log_odds': log_odds, 'tfd': tfd}
        
        return pd.DataFrame.from_dict(log_odds_tfd, orient='index')
    
    # Process each channel
    for channel, group in df.groupby('channel_name'):
        try:
            # Get preprocessed content (already tokenized)
            channel_docs = group['preprocessed_content'].tolist()
            all_docs = df['preprocessed_content'].tolist()
            
            # Calculate statistics
            results_df = calculate_channel_stats(channel_docs, all_docs)
            results_df.index.name = 'term'
            
            # Create visualization
            plt.figure(figsize=(12, 8))
            plt.scatter(results_df['tfd'], results_df['log_odds'], alpha=0.5)
            plt.xlabel('Term Frequency Distribution (TFD)')
            plt.ylabel('Log-Odds Ratio')
            plt.title(f'Log-Odds vs TFD for {channel}')
            
            # Add annotations for extreme points
            extreme_points = results_df.nlargest(10, 'log_odds')
            for term in extreme_points.index:
                plt.annotate(
                    term,
                    xy=(extreme_points.loc[term, 'tfd'], 
                        extreme_points.loc[term, 'log_odds']),
                    xytext=(5, 5),
                    textcoords='offset points'
                )
            
            # Save plot and data
            safe_channel_name = "".join(x for x in channel if x.isalnum() or x in (' ', '-', '_'))
            plt.savefig(os.path.join(output_dir, f'{safe_channel_name}_log_odds_tfd.png'),
                       bbox_inches='tight', dpi=300)
            plt.close()
            
            results_df.to_csv(
                os.path.join(output_dir, f'{safe_channel_name}_log_odds_tfd.csv'),
                index=True
            )
            
            print(f"Created Log-Odds vs TFD analysis for {channel}")
            
        except Exception as e:
            print(f"Error processing channel {channel}: {str(e)}")
            continue

# Execute the analysis
calculate_log_odds_vs_tfd(df_metadata_transcript)
# Out:
# Created Log-Odds vs TFD analysis for AlvinBlox
# Created Log-Odds vs TFD analysis for Beginner's Code Zone
# Created Log-Odds vs TFD analysis for Black Girls Code
# Created Log-Odds vs TFD analysis for Brackeys
# Created Log-Odds vs TFD analysis for Bro Code
# Created Log-Odds vs TFD analysis for CS Dojo
# Created Log-Odds vs TFD analysis for CS50 Made Easy with Rahul
# Created Log-Odds vs TFD analysis for Cave of Programming
# Created Log-Odds vs TFD analysis for Clear Code
# Created Log-Odds vs TFD analysis for Clever Programmer
# Created Log-Odds vs TFD analysis for Code Monkey
# Created Log-Odds vs TFD analysis for Code With Conner
# Created Log-Odds vs TFD analysis for Code.org
# Created Log-Odds vs TFD analysis for CodeBeauty
# Created Log-Odds vs TFD analysis for CodeMonkey - Coding Games for Kids
# Created Log-Odds vs TFD analysis for CodeWithChris
# Created Log-Odds vs TFD analysis for Codecademy
# Created Log-Odds vs TFD analysis for Coding Kids
# Created Log-Odds vs TFD analysis for Coding With Kids
# Created Log-Odds vs TFD analysis for Coding Workshops for Kids - Online Coding Courses for Kids and Parents
# Created Log-Odds vs TFD analysis for Coding for kids
# Created Log-Odds vs TFD analysis for Coding is for girls
# Created Log-Odds vs TFD analysis for Coding with John
# Created Log-Odds vs TFD analysis for Coding with Mat
# Created Log-Odds vs TFD analysis for CodingNepal
# Created Log-Odds vs TFD analysis for Codingal Education
# Created Log-Odds vs TFD analysis for Computer World Kids
# Created Log-Odds vs TFD analysis for Corey Schafer
# Created Log-Odds vs TFD analysis for Easy Codes for Kids
# Created Log-Odds vs TFD analysis for First Code Academy
# Created Log-Odds vs TFD analysis for GIRLS CODE TOO!
# Created Log-Odds vs TFD analysis for Girls Who Code
# Created Log-Odds vs TFD analysis for Girls Will Code
# Created Log-Odds vs TFD analysis for GirlsCodeIt
# Created Log-Odds vs TFD analysis for Hackingtons Code School
# Created Log-Odds vs TFD analysis for Jenny's Lectures CS IT
# Created Log-Odds vs TFD analysis for Khan Academy Computing
# Created Log-Odds vs TFD analysis for Kidicode Ninja: Coding for Beginners and Kids
# Created Log-Odds vs TFD analysis for Kids Coding Club
# Created Log-Odds vs TFD analysis for Kids Coding Playground
# Created Log-Odds vs TFD analysis for Kids for Code
# Created Log-Odds vs TFD analysis for KidsCanCode
# Created Log-Odds vs TFD analysis for Kodable
# Created Log-Odds vs TFD analysis for Learn Computer Programming
# Created Log-Odds vs TFD analysis for LearnCode.academy
# Created Log-Odds vs TFD analysis for Low Level Learning
# Created Log-Odds vs TFD analysis for MrBrownCS
# Created Log-Odds vs TFD analysis for My CS
# Created Log-Odds vs TFD analysis for Programiz
# Created Log-Odds vs TFD analysis for Programming For Beginners
# Created Log-Odds vs TFD analysis for Programming Kids
# Created Log-Odds vs TFD analysis for Programming with Mosh
# Created Log-Odds vs TFD analysis for ProgrammingKnowledge
# Created Log-Odds vs TFD analysis for STEMinGames - Beginner Programming
# Created Log-Odds vs TFD analysis for Scratch Team
# Created Log-Odds vs TFD analysis for ShawCode
# Created Log-Odds vs TFD analysis for Tech With Tim
# Created Log-Odds vs TFD analysis for TechWorld with Nana
# Created Log-Odds vs TFD analysis for The BlackFemale Engineer
# Created Log-Odds vs TFD analysis for The Coding Train
# Created Log-Odds vs TFD analysis for freeCodeCamp.org
# Created Log-Odds vs TFD analysis for griffpatch
# Created Log-Odds vs TFD analysis for mycodeschool
# Created Log-Odds vs TFD analysis for thenewboston
# Created Log-Odds vs TFD analysis for w3schools.com

# %% [markdown]
# # Log-Likelihodo Ratio (LLR), Fightin'Words, and Frequency Shifts
# i think these will probably do better for visualizing relationships between different YouTube Videos and Channels

# %% [markdown]
# ## Log-Likelihood Ratio (LLR)
# - [DEF]: Statistical method that compares frequency of words in two different corpora, determining which words are more strongly associated with one corpus; essentially, we find distinctive words between two groups of texts, where that set of distinctive words is more associated with one group than another (positive vs. negative review language)! what words are "over-represented" and "under-represented" in one group of texts compared to another?
# - In the context of our data, it would help:
#     - Determine which words are significantly overrepresented or underrepresented in one group of video transcripts compared to another
#     - Identify characteristic vocabulary that distinguishes different channels or video categories
#     - Quantify the strength of association between specific words and YouTube Channels
# - How does this differ from what we've done before (TFs, TFDs, TF-IDFs...)?
#     - Compares word frequencies between two different corpora statistically, instead of multiple TF by IDF
#     - Tests whether word frequency differences between groups are statistically significant
#     - Better suited for comparing entire collections against each other
#     - Accounts for both presence and absence of terms
# - Interpretation:
#     - A higher LLR score for a word in a specific channel indicates the word is distinctively assocaited with that channel's content
#     - Simultaneiously, the score measures how unlikely it is that the word's frequency in that channel occured by chance compared to its appear across all channels
#     - And it's statistically significant!!!
# - Implementation: use just python's math library OR scipy.stats to manually code an implementation, or we can just find one online and adapt it for our uses... because it's literally just a bunch of math to code LLR tbh
#
# We will produce comparisons between YouTube channels, with BGC being our northstar comparison.
#
# NOTE: LLR vs. frequency visualization

# %%
# def process_channel_content(texts):
#     """Process content for a single channel"""
#     processed = []
#     for text in texts:
#         if isinstance(text, str):
#             words = text.strip('[]').replace("'", "").split(',')
#             processed.extend([word.strip() for word in words 
#                             if len(word.strip()) > 1 and word.strip().isalnum()])
#     return processed

# def calculate_pairwise_llr(texts1, texts2):
#     """Calculate LLR scores between two channels"""
#     # Process texts for both channels
#     words1 = process_channel_content(texts1)
#     words2 = process_channel_content(texts2)
    
#     # Get word counts for both channels
#     counts1 = Counter(words1)
#     counts2 = Counter(words2)
    
#     total_words1 = sum(counts1.values())
#     total_words2 = sum(counts2.values())
    
#     # Calculate LLR for each word
#     word_llrs = {}
#     vocab = set(counts1.keys()) | set(counts2.keys())
    
#     for word in vocab:
#         if (counts1.get(word, 0) + counts2.get(word, 0)) >= 2:
#             # Contingency table values
#             a = counts1.get(word, 0)  # word count in channel 1
#             b = total_words1 - a      # non-word count in channel 1
#             c = counts2.get(word, 0)  # word count in channel 2
#             d = total_words2 - c      # non-word count in channel 2
            
#             contingency = np.array([[a, b], [c, d]])
            
#             try:
#                 llr_stat = chi2_contingency(contingency, lambda_="log-likelihood")[0]
#                 word_llrs[word] = {
#                     'llr_score': llr_stat,
#                     'count_channel1': a,
#                     'count_channel2': c
#                 }
#             except ValueError:
#                 continue
    
#     return word_llrs

# def analyze_bgc_pairwise_llr(df):
#     """Analyze Black Girls Code against all other channels using LLR"""
#     # Create output directory
#     output_dir = 'black_girls_code_llr_comparisons'
#     os.makedirs(output_dir, exist_ok=True)
    
#     # Get Black Girls Code content
#     bgc_texts = df[df['channel_name'] == 'Black Girls Code']['preprocessed_content'].tolist()
#     if not bgc_texts:
#         raise ValueError("No Black Girls Code content found in dataset")
    
#     results = {}
#     all_comparisons = []
    
#     # Compare with each other channel
#     for channel in df['channel_name'].unique():
#         if channel != 'Black Girls Code':
#             try:
#                 # Get channel texts
#                 other_texts = df[df['channel_name'] == channel]['preprocessed_content'].tolist()
                
#                 # Calculate LLR scores
#                 word_llrs = calculate_pairwise_llr(bgc_texts, other_texts)
                
#                 if word_llrs:
#                     # Convert to DataFrame
#                     comparison = pd.DataFrame.from_dict(word_llrs, orient='index')
#                     comparison['word'] = comparison.index
#                     comparison = comparison.sort_values('llr_score', ascending=False)
                    
#                     # Save individual comparison
#                     safe_channel = "".join(x for x in channel if x.isalnum() or x in (' ', '-', '_'))
#                     filename = f'BGC_vs_{safe_channel}_llr.csv'
#                     filepath = os.path.join(output_dir, filename)
#                     comparison.to_csv(filepath, index=False)
                    
#                     results[channel] = comparison
#                     all_comparisons.append(comparison.assign(compared_channel=channel))
                    
#                     print(f"\nCompleted LLR comparison: Black Girls Code vs {channel}")
#                     if len(comparison) > 0:
#                         print("\nTop 10 words by LLR score:")
#                         print(comparison[['word', 'llr_score', 'count_channel1', 'count_channel2']].head(10))
                
#             except Exception as e:
#                 print(f"Error comparing with {channel}: {str(e)}")
#                 continue
    
#     # Save combined results
#     if all_comparisons:
#         combined = pd.concat(all_comparisons, ignore_index=True)
#         combined.to_csv(os.path.join(output_dir, 'all_llr_comparisons.csv'), index=False)
#         print("\nSaved combined LLR comparisons file")
    
#     return results

# def main(df):
#     """Main analysis pipeline"""
#     if df['preprocessed_content'].isna().all():
#         raise ValueError("No valid content found in preprocessed_content column")
    
#     print("Starting Black Girls Code LLR comparisons...")
#     results = analyze_bgc_pairwise_llr(df)
#     print("LLR Analysis complete!")
#     return results

# # Run the analysis
# if __name__ == "__main__":
#     results = main(df_metadata_transcript)
# Out:
# Starting Black Girls Code LLR comparisons...
#
# Completed LLR comparison: Black Girls Code vs Codecademy
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1107.230000             246              27
# black    black   911.628811             245              85
# block    block   749.612132             250             177
# art        art   384.290527             118              65
# woman    woman   377.511784             111              53
# data      data   364.893311              29            3607
# sprite  sprite   348.185160              86              19
# afro      afro   273.434983              54               0
# game      game   268.524805             217             618
# young    young   192.461704              56              25
#
# Completed LLR comparison: Black Girls Code vs Coding for kids
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# print    print  540.548529               2             419
# let        let  539.116705             341            1262
# one        one  393.961722             371            1146
# girl      girl  333.327519             246               1
# list      list  329.400244              20             338
# black    black  290.790732             245               7
# equal    equal  283.629249              35             347
# python  python  243.268136               7             221
# put        put  223.388553              75             391
# two        two  205.971706             108             442
#
# Completed LLR comparison: Black Girls Code vs Scratch Team
#
# Top 10 words by LLR score:
#               word    llr_score  count_channel1  count_channel2
# scratch    scratch  1147.709386              50            1761
# project    project   596.511232              53            1075
# black        black   373.854449             245              25
# girl          girl   368.161419             246              27
# woman        woman   213.458715             111               2
# sort          sort   209.329383              23             403
# career      career   200.823251             108               3
# function  function   199.664628             101               1
# tech          tech   189.621653             108               5
# could        could   136.054150              94             562
#
# Completed LLR comparison: Black Girls Code vs Code.org
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# computer  computer  722.480599              39            4923
# student    student  572.226702              21            3631
# black        black  556.094554             245             214
# girl          girl  531.529976             246             236
# science    science  482.113187              22            3186
# teacher    teacher  323.679857              10            2008
# add            add  261.527814             257             634
# canvas      canvas  245.997015              73              20
# afro          afro  245.279799              54               0
# script      script  219.362009              61              12
#
# Completed LLR comparison: Black Girls Code vs Khan Academy Computing
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# girl          girl  368.715322             246               0
# block        block  240.002565             250              26
# tag            tag  239.551086               7             235
# black        black  233.366300             245              26
# number      number  222.561538              26             290
# browser    browser  221.627075               2             195
# people      people  216.026537             297              55
# function  function  213.855267             101             473
# cs              cs  206.831469               2             183
# thank        thank  203.836258             153               3
#
# Completed LLR comparison: Black Girls Code vs Programiz
#
# Top 10 words by LLR score:
#               word    llr_score  count_channel1  count_channel2
# ill            ill  1687.824113             128            4182
# number      number   910.425769              26            1886
# print        print   827.607705               2            1449
# im              im   786.680419             513             148
# function  function   670.937562             101            2046
# think        think   669.056652             317              32
# girl          girl   664.687746             246               0
# run            run   660.705307              37            1543
# black        black   642.378355             245               2
# equal        equal   617.214266              35            1446
#
# Completed LLR comparison: Black Girls Code vs Clear Code
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# people  people  1294.977065             297              47
# girl      girl  1250.442966             246               4
# know      know  1059.158250             599            1185
# want      want  1051.393634             491           20933
# love      love   782.129864             152               1
# thank    thank   763.871531             153               4
# self      self   683.016611               6            5005
# woman    woman   576.179215             111               0
# one        one   552.933470             371           13484
# career  career   543.191747             108               2
#
# Completed LLR comparison: Black Girls Code vs w3schools.com
#
# Top 10 words by LLR score:
#                 word    llr_score  count_channel1  count_channel2
# element      element  1209.118911              12             513
# html            html   678.654834               5             285
# cs                cs   574.780920               2             235
# style          style   442.258347               9             201
# image          image   406.088369               5             177
# text            text   376.233270              36             220
# page            page   351.893513              27             196
# attribute  attribute   327.590573               0             131
# property    property   308.452733              23             171
# im                im   296.780402             513               4
#
# Completed LLR comparison: Black Girls Code vs KidsCanCode
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# girl      girl  763.875907             246               0
# people  people  663.423192             297              51
# black    black  524.203466             245              49
# block    block  508.347056             250              59
# thank    thank  433.402445             153               5
# love      love  412.965980             152               8
# player  player  390.799847              49            1427
# tile      tile  381.931721               0             830
# set        set  373.460468              68            1548
# think    think  364.300351             317             224
#
# Completed LLR comparison: Black Girls Code vs Girls Who Code
#
# Top 10 words by LLR score:
#                 word   llr_score  count_channel1  count_channel2
# block          block  506.768291             250               5
# black          black  261.060652             245              72
# color          color  192.372742             142              25
# company      company  188.330793              44             497
# let              let  186.144376             341             216
# sprite        sprite  184.398257              86               0
# add              add  180.129642             257             130
# interview  interview  166.403317               3             245
# variable    variable  157.848968              74               0
# art              art  153.030112             118              23
#
# Completed LLR comparison: Black Girls Code vs freeCodeCamp.org
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  2301.400142             246             175
# black    black  1208.168317             245            2600
# woman    woman   818.236552             111             296
# art        art   639.192904             118             952
# afro      afro   605.298614              54               2
# block    block   572.348915             250           11422
# career  career   554.066685             108            1017
# love      love   546.522900             152            3315
# thank    thank   531.014978             153            3574
# tech      tech   506.032196             108            1295
#
# Completed LLR comparison: Black Girls Code vs LearnCode.academy
#
# Top 10 words by LLR score:
#         word   llr_score  count_channel1  count_channel2
# girl    girl  681.687060             246               1
# go        go  609.491263             357            3587
# game    game  582.463365             217               3
# black  black  460.017769             245              48
# let      let  395.719594             341            2901
# thank  thank  347.878231             153              13
# block  block  344.176424             250             101
# art      art  311.449562             118               2
# woman  woman  308.317496             111               0
# think  think  299.370520             317             217
#
# Completed LLR comparison: Black Girls Code vs Code Monkey
#
# Top 10 words by LLR score:
#                     word    llr_score  count_channel1  count_channel2
# girl                girl  1568.947357             246              11
# black              black   942.212375             245             286
# block              block   936.447644             250             314
# know                know   832.273645             599            3732
# woman              woman   692.454660             111               7
# let                  let   666.528333             341           30328
# career            career   589.806219             108              28
# game                game   485.959463             217           20647
# people            people   426.217292             297            1784
# opportunity  opportunity   420.560719              80              26
#
# Completed LLR comparison: Black Girls Code vs Corey Schafer
#
# Top 10 words by LLR score:
#         word    llr_score  count_channel1  count_channel2
# girl    girl  1008.413587             246               5
# black  black   859.283457             245              33
# game    game   846.344239             217              11
# file    file   694.425212              20            3471
# run      run   545.293433              37            3211
# dot      dot   543.288238               1            2277
# love    love   529.234053             152              21
# block  block   505.126066             250             202
# see      see   494.457229             226            5892
# woman  woman   461.250412             111               1
#
# Completed LLR comparison: Black Girls Code vs TechWorld with Nana
#
# Top 10 words by LLR score:
#                     word    llr_score  count_channel1  count_channel2
# application  application  1043.550055               4            3074
# black              black   883.357506             245               0
# girl                girl   876.246798             246               1
# docker            docker   761.138709               0            2162
# container      container   711.929998               0            2024
# game                game   695.697960             217              12
# service          service   681.630444               5            2076
# cluster          cluster   627.493930               0            1787
# kubernetes    kubernetes   601.149699               0            1713
# file                file   535.630997              20            1939
#
# Completed LLR comparison: Black Girls Code vs Clever Programmer
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1403.863669             246             227
# black    black   960.770775             245             743
# block    block   959.028234             250             799
# woman    woman   768.042376             111              33
# sprite  sprite   691.652985              86               2
# art        art   685.476129             118              99
# guy        guy   650.621413              75           35373
# go          go   504.383283             357           61731
# canvas  canvas   476.753338              73              32
# let        let   472.184500             341           58499
#
# Completed LLR comparison: Black Girls Code vs CodeBeauty
#
# Top 10 words by LLR score:
#             word   llr_score  count_channel1  count_channel2
# number    number  823.296673              26            2651
# black      black  756.815630             245              12
# girl        girl  743.827711             246              15
# say          say  726.205526             167            3986
# think      think  624.011080             317             125
# array      array  558.738971               3            1540
# thats      thats  541.339817             291             130
# know        know  537.546405             599             732
# pointer  pointer  496.936200               2            1356
# user        user  495.449861              20            1668
#
# Completed LLR comparison: Black Girls Code vs Coding with John
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# method  method  1016.955629               1            1402
# java      java   709.448043               3            1013
# number  number   678.481145              26            1179
# class    class   655.887716               9            1004
# array    array   589.847815               3             850
# black    black   570.381946             245               0
# girl      girl   562.369489             246               1
# print    print   433.828428               2             625
# string  string   420.963468               1             595
# im          im   353.853754             513             305
#
# Completed LLR comparison: Black Girls Code vs griffpatch
#
# Top 10 words by LLR score:
#             word   llr_score  count_channel1  count_channel2
# girl        girl  870.590273             246               0
# know        know  728.640791             599             572
# costume  costume  728.549814               2            2056
# people    people  712.440136             297              75
# tile        tile  573.312470               0            1576
# sprite    sprite  530.875163              86            2692
# black      black  466.366258             245             114
# youre      youre  433.859303             252             143
# player    player  412.286290              49            1891
# woman      woman  388.516773             111               0
#
# Completed LLR comparison: Black Girls Code vs My CS
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1163.992353             246              21
# black    black   952.790564             245              80
# game      game   709.341155             217             133
# block    block   574.906165             250             342
# love      love   558.867955             152              62
# minus    minus   487.026037               1            3498
# career  career   471.050834             108              18
# tech      tech   453.632388             108              23
# sprite  sprite   450.034037              86               0
# woman    woman   435.369238             111              34
#
# Completed LLR comparison: Black Girls Code vs CodingNepal
#
# Top 10 words by LLR score:
#             word    llr_score  count_channel1  count_channel2
# foreign  foreign  1872.542742              41             560
# still      still   782.130518              60             283
# thank      thank   505.960313             153             263
# nothing  nothing   413.137305               9             126
# know        know   361.748523             599             392
# season    season   341.590912               2              96
# slowly    slowly   263.852177               3              77
# came        came   218.650396              21              84
# breathe  breathe   197.947842               1              56
# hiding    hiding   186.671659               1              53
#
# Completed LLR comparison: Black Girls Code vs AlvinBlox
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# player  player  972.566394              49            3448
# girl      girl  855.342783             246               0
# black    black  617.461092             245              47
# dot        dot  600.472063               1            1624
# script  script  531.873062              61            2327
# people  people  488.354390             297             173
# love      love  468.683963             152               8
# item      item  460.691164               6            1366
# table    table  418.391430              15            1404
# data      data  401.784661              29            1553
#
# Completed LLR comparison: Black Girls Code vs thenewboston
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1102.739175             246              52
# ahead    ahead   971.620551              30            9558
# black    black   937.208182             245             112
# woman    woman   587.118888             111               3
# art        art   498.637448             118              34
# career  career   498.373077             108              18
# game      game   456.757587             217             407
# people  people   455.897308             297             848
# sprite  sprite   455.681776              86               2
# tech      tech   448.043256             108              34
#
# Completed LLR comparison: Black Girls Code vs CS Dojo
#
# Top 10 words by LLR score:
#             word   llr_score  count_channel1  count_channel2
# black      black  570.437590             245               5
# girl        girl  547.326712             246               9
# block      block  371.518840             250              58
# array      array  313.230580               3             522
# number    number  297.868699              26             689
# example  example  275.304250              21             616
# woman      woman  273.747823             111               0
# game        game  266.746436             217              74
# problem  problem  250.794555              25             602
# art          art  245.776541             118               7
#
# Completed LLR comparison: Black Girls Code vs CodeWithChris
#
# Top 10 words by LLR score:
#         word    llr_score  count_channel1  count_channel2
# girl    girl  1262.874309             246              15
# black  black   959.856387             245             104
# view    view   924.402805               5            7845
# app      app   631.423112              21            6373
# woman  woman   596.483635             111               2
# block  block   515.325180             250             491
# love    love   496.427153             152             117
# tech    tech   489.760771             108              21
# art      art   484.657332             118              40
# data    data   472.670045              29            5379
#
# Completed LLR comparison: Black Girls Code vs Programming with Mosh
#
# Top 10 words by LLR score:
#                     word    llr_score  count_channel1  count_channel2
# girl                girl  1040.359373             246               0
# black              black   855.086673             245              31
# know                know   762.142090             599             905
# game                game   603.928138             217              77
# people            people   549.699717             297             269
# think              think   547.153489             317             321
# method            method   509.673170               1            2083
# class              class   441.542880               9            2061
# really            really   436.839167             341             509
# application  application   433.705517               4            1886
#
# Completed LLR comparison: Black Girls Code vs Brackeys
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1232.644099             246               8
# know      know   918.536802             599            1455
# block    block   826.505667             250             146
# black    black   724.348487             245             195
# woman    woman   563.831873             111               2
# people  people   561.683433             297             548
# career  career   522.596833             108               6
# unity    unity   480.963389               2            3489
# hit        hit   462.138040               7            3634
# let        let   390.353307             341           11408
#
# Completed LLR comparison: Black Girls Code vs Bro Code
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1375.940449             246               4
# know      know  1373.494651             599            1118
# let        let   832.497827             341           20314
# black    black   809.002582             245             211
# thank    thank   780.455934             153              15
# people  people   774.412441             297             438
# love      love   729.533631             152              26
# within  within   679.251200              21            7398
# method  method   664.000199               1            5955
# equal    equal   646.193948              35            7797
#
# Completed LLR comparison: Black Girls Code vs The Coding Train
#
# Top 10 words by LLR score:
#               word    llr_score  count_channel1  count_channel2
# girl          girl  1667.622977             246             101
# block        block  1115.863273             250             586
# black        black   865.370437             245            1014
# career      career   783.017153             108              25
# im              im   780.089142             513           97416
# woman        woman   670.076949             111              86
# tech          tech   589.515728             108             129
# afro          afro   448.291823              54               0
# industry  industry   405.059518              63              34
# sprite      sprite   398.193692              86             178
#
# Completed LLR comparison: Black Girls Code vs mycodeschool
#
# Top 10 words by LLR score:
#             word    llr_score  count_channel1  count_channel2
# node        node  1486.614548               0            1919
# array      array  1003.333618               3            1344
# address  address   721.286601              12            1069
# element  element   685.767547              12            1022
# list        list   633.740433              20            1017
# pointer  pointer   570.057199               2             772
# girl        girl   552.908762             246               0
# black      black   540.301242             245               1
# people    people   540.058360             297              20
# know        know   534.379436             599             247
#
# Completed LLR comparison: Black Girls Code vs Programming For Beginners
#
# Top 10 words by LLR score:
#             word    llr_score  count_channel1  count_channel2
# know        know  1931.804810             599             174
# guy          guy  1908.291234              75           11151
# provide  provide  1496.948188               3            6979
# really    really  1490.286763             341               5
# think      think  1407.789749             317               2
# file        file  1251.792313              20            6509
# im            im  1222.549883             513             360
# girl        girl  1106.790833             246               0
# case        case  1061.097977              10            5288
# tag          tag   896.222669               7            4420
#
# Completed LLR comparison: Black Girls Code vs Code With Conner
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# value    value  511.054418              86             496
# pin        pin  461.800292               1             261
# print    print  389.275482               2             226
# string  string  297.355014               1             171
# led        led  285.685504               5             180
# girl      girl  245.067853             246               0
# sensor  sensor  209.655002               0             118
# loop      loop  200.577990              45             216
# black    black  196.530284             245               7
# lesson  lesson  193.801484               6             131
#
# Completed LLR comparison: Black Girls Code vs Learn Computer Programming
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# number  number  855.743159              26             875
# equal    equal  854.475640              35             915
# dot        dot  750.005628               1             640
# index    index  733.706340               0             617
# string  string  709.124508               1             606
# im          im  682.339445             513              18
# give      give  612.542536             102             929
# print    print  603.463057               2             526
# plus      plus  569.944240              26             624
# value    value  534.170942              86             802
#
# Completed LLR comparison: Black Girls Code vs First Code Academy
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# click    click  565.713037             123            1148
# know      know  552.023586             599             138
# girl      girl  454.849654             246               0
# people  people  444.710282             297              16
# im          im  434.730498             513            2041
# think    think  357.209548             317              48
# really  really  280.624249             341              93
# black    black  263.823068             245              41
# change  change  261.830837             158             844
# love      love  254.644338             152               3
#
# Completed LLR comparison: Black Girls Code vs STEMinGames - Beginner Programming
#
# Top 10 words by LLR score:
#                 word   llr_score  count_channel1  count_channel2
# make            make  256.339369             319             377
# he                he  254.559429               6             111
# pizza          pizza  243.185493               0              92
# lesson        lesson  207.703015               6              93
# clone          clone  205.185050               0              78
# know            know  199.120879             599              29
# flag            flag  190.557885              19             106
# character  character  189.027711              71             159
# green          green  172.596778              60             141
# scratch      scratch  171.001289              50             131
#
# Completed LLR comparison: Black Girls Code vs Coding with Mat
#
# Top 10 words by LLR score:
#                   word   llr_score  count_channel1  count_channel2
# cmake            cmake  404.116893               0              83
# file              file  181.836722              20              54
# plus              plus  176.973534              26              56
# program        program  170.074081              59              68
# project        project  155.846220              53              62
# directory    directory  151.173719               0              32
# window          window  126.515919               0              27
# simple          simple  118.010859               6              31
# executable  executable  106.822635               0              23
# compiler      compiler  101.904893               0              22
#
# Completed LLR comparison: Black Girls Code vs Hackingtons Code School
#
# Top 10 words by LLR score:
#             word   llr_score  count_channel1  count_channel2
# go            go  405.831046             357             672
# let          let  334.153012             341             600
# game        game  280.583637             217             436
# costume  costume  208.720949               2             109
# ahead      ahead  206.394005              30             165
# girl        girl  202.968438             246               0
# people    people  198.169243             297               7
# black      black  161.672230             245               6
# know        know  160.337302             599              93
# clone      clone  144.178335               0              71
#
# Completed LLR comparison: Black Girls Code vs The BlackFemale Engineer
#
# Top 10 words by LLR score:
#               word  llr_score  count_channel1  count_channel2
# license    license  85.146325               2              18
# app            app  83.390105              21              26
# readme      readme  78.452043               0              15
# provide    provide  70.752046               3              16
# piggy        piggy  67.171664               0              13
# language  language  54.514321              13              17
# example    example  52.952254              21              19
# github      github  50.305979               0              10
# udemy        udemy  44.704264               0               9
# link          link  40.768589              17              15
#
# Completed LLR comparison: Black Girls Code vs Codingal Education
#
# Top 10 words by LLR score:
#                     word   llr_score  count_channel1  count_channel2
# ill                  ill  274.073712             128              63
# fish                fish  129.545226               0              17
# shark              shark   92.000290               1              13
# octopus          octopus   89.209854               0              12
# project          project   70.112229              53              19
# register        register   49.137164               0               7
# lab                  lab   43.321000               5               8
# eat                  eat   34.754029               2               6
# competition  competition   34.754029               2               6
# sprite            sprite   33.449168              86              14
#
# Completed LLR comparison: Black Girls Code vs ShawCode
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# print        print  866.022018               2             303
# equal        equal  562.014410              35             258
# string      string  430.194425               1             152
# python      python  352.630445               7             139
# variable  variable  327.103562              74             209
# list          list  298.967746              20             140
# hello        hello  256.197530              17             120
# file          file  251.103310              20             122
# run            run  249.953640              37             141
# item          item  221.959140               6              91
#
# Completed LLR comparison: Black Girls Code vs Low Level Learning
#
# Top 10 words by LLR score:
#                 word   llr_score  count_channel1  count_channel2
# stack          stack  220.595178               3              65
# pointer      pointer  215.235986               2              62
# program      program  178.534377              59              96
# array          array  161.159261               3              49
# function    function  159.864335             101             110
# return        return  154.474924               8              53
# code            code  145.829409             270             168
# file            file  140.101291              20              59
# structure  structure  133.861235               5              44
# type            type  120.380870              49              70
#
# Completed LLR comparison: Black Girls Code vs ProgrammingKnowledge
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1825.692479             246               5
# people  people  1457.170841             297             298
# really  really  1169.462158             341             930
# black    black  1008.382040             245             427
# love      love   956.726638             152              42
# youre    youre   842.305942             252             724
# woman    woman   760.372347             111              13
# career  career   714.117363             108              19
# art        art   707.649845             118              45
# file      file   697.854925              20           19438
#
# Completed LLR comparison: Black Girls Code vs Cave of Programming
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# girl      girl  747.828573             246               0
# black    black  657.776737             245              12
# class    class  512.898997               9            1223
# love      love  449.399082             152               1
# string  string  443.212937               1             948
# let        let  433.298817             341            3449
# method  method  408.822557               1             877
# game      game  403.962183             217              60
# run        run  386.171116              37            1255
# know      know  378.600404             599             712
#
# Completed LLR comparison: Black Girls Code vs MrBrownCS
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# print    print  332.593234               2             194
# number  number  314.252208              26             251
# string  string  294.992826               1             169
# list      list  272.229551              20             212
# girl      girl  243.826542             246               0
# black    black  233.546317             245               1
# python  python  226.402036               7             152
# input    input  224.744187               5             145
# index    index  199.533412               0             112
# item      item  182.548474               6             124
#
# Completed LLR comparison: Black Girls Code vs CS50 Made Easy with Rahul
#
# Top 10 words by LLR score:
#                 word   llr_score  count_channel1  count_channel2
# print          print  472.049467               2             191
# let              let  389.863216             341             502
# need            need  306.791890             201             344
# number        number  294.337974              26             166
# vote            vote  274.241996               3             117
# user            user  244.867504              20             136
# sort            sort  241.835858              23             139
# candidate  candidate  201.341785               0              80
# plus            plus  196.588782              26             123
# string        string  177.692303               1              74
#
# Completed LLR comparison: Black Girls Code vs Coding is for girls
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# python  python  635.596806               7             264
# file      file  492.204243              20             235
# email    email  317.521217               7             141
# type      type  273.778860              49             183
# number  number  244.766767              26             142
# name      name  233.597215              86             201
# error    error  227.299142               3              97
# print    print  215.505722               2              90
# method  method  188.565073               1              77
# list      list  182.383363              20             107
#
# Completed LLR comparison: Black Girls Code vs CodeMonkey - Coding Games for Kids
#
# Top 10 words by LLR score:
#                 word    llr_score  count_channel1  count_channel2
# student      student  1255.961892              21            2269
# monkey        monkey   954.923997               0            1517
# classroom  classroom   695.978507               4            1173
# black          black   553.347126             245              11
# girl            girl   539.809021             246              14
# course        course   525.579453              40            1229
# teacher      teacher   483.697701              10             902
# challenge  challenge   359.189047              46             973
# code            code   356.848181             270            2108
# coding        coding   346.978141              69            1093
#
# Completed LLR comparison: Black Girls Code vs Kids Coding Playground
#
# Top 10 words by LLR score:
#             word   llr_score  count_channel1  count_channel2
# girl        girl  799.719442             246              34
# people    people  721.921934             297             128
# one          one  663.482058             371            7656
# costume  costume  614.666051               2            2284
# love        love  531.409846             152              12
# let          let  512.206621             341            6519
# black      black  432.032917             245             205
# woman      woman  426.114928             111               2
# set          set  423.661764              68            2815
# put          put  405.633229              75            2838
#
# Completed LLR comparison: Black Girls Code vs Kids for Code
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# print        print  647.261122               2             216
# tag            tag  355.325453               7             132
# equal        equal  321.238447              35             157
# list          list  268.497090              20             121
# string      string  205.749605               1              71
# word          word  201.601227              21              98
# variable  variable  189.067968              74             138
# integer    integer  179.766012               0              60
# quote        quote  171.962899               3              64
# inside      inside  163.101109              45             105
#
# Completed LLR comparison: Black Girls Code vs Kodable
#
# Top 10 words by LLR score:
#             word    llr_score  count_channel1  count_channel2
# student  student  1061.207898              21            1156
# class      class   638.336300               9             676
# lesson    lesson   525.287668               6             548
# codable  codable   486.598838               0             463
# black      black   416.973044             245               1
# girl        girl   410.139631             246               2
# teacher  teacher   356.141144              10             409
# fuzz        fuzz   337.268382               0             323
# block      block   323.323854             250              19
# coding    coding   266.790776              69             541
#
# Completed LLR comparison: Black Girls Code vs GIRLS CODE TOO!
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# email        email  544.063657               7             187
# php            php  432.149595               0             136
# equal        equal  413.076865              35             183
# ahead        ahead  356.669344              30             158
# tutorial  tutorial  343.373911               8             125
# file          file  308.415345              20             130
# variable  variable  304.221601              74             179
# echo          echo  254.347161               0              81
# dot            dot  239.495673               1              79
# table        table  222.942423              15              95
#
# Completed LLR comparison: Black Girls Code vs Kidicode Ninja: Coding for Beginners and Kids
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# let            let  415.625105             341             657
# im              im  322.824019             513             739
# know          know  318.719135             599              32
# say            say  295.443853             167             390
# one            one  259.437340             371             559
# go              go  225.992404             357             517
# clicked    clicked  225.824794               5             125
# tutorial  tutorial  210.690778               8             125
# girl          girl  200.684489             246               0
# see            see  198.272284             226             376
#
# Completed LLR comparison: Black Girls Code vs GirlsCodeIt
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# class    class  505.246846               9             743
# print    print  431.114385               2             581
# black    black  426.404350             245              19
# number  number  343.760852              26             644
# string  string  342.202788               1             456
# love      love  297.396584             152               5
# block    block  293.148972             250              64
# method  method  278.845557               1             375
# equal    equal  277.167271              35             598
# array    array  270.860501               3             385
#
# Completed LLR comparison: Black Girls Code vs Easy Codes for Kids
#
# Top 10 words by LLR score:
#             word   llr_score  count_channel1  count_channel2
# go            go  873.670011             357             764
# ahead      ahead  760.674331              30             356
# let          let  669.171697             341             644
# little    little  468.757570             107             333
# costume  costume  241.723791               2              99
# picture  picture  213.332546              10             104
# clicked  clicked  190.604192               5              86
# hide        hide  168.073159               6              79
# shop        shop  161.760873               1              66
# know        know  159.150246             599              45
#
# Completed LLR comparison: Black Girls Code vs Coding With Kids
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# one        one  561.735489             371            2577
# two        two  518.728341             108            1400
# know      know  517.221902             599             276
# girl      girl  484.298681             246              12
# number  number  374.246212              26             727
# agent    agent  371.667202               2             534
# people  people  368.090459             297              78
# print    print  359.867409               2             518
# want      want  315.052952             491             306
# really  really  307.522892             341             148
#
# Completed LLR comparison: Black Girls Code vs Programming Kids
#
# Top 10 words by LLR score:
#                     word   llr_score  count_channel1  count_channel2
# python            python  504.940270               7             176
# dot                  dot  333.105075               1             109
# type                type  303.120632              49             159
# enter              enter  242.692803              13             100
# let                  let  235.496222             341             303
# bracket          bracket  210.802945               0              68
# name                name  208.742246              86             150
# list                list  204.618629              20              95
# turtle            turtle  185.237219               0              60
# programming  programming  178.248470              13              78
#
# Completed LLR comparison: Black Girls Code vs Kids Coding Club
#
# Top 10 words by LLR score:
#               word  llr_score  count_channel1  count_channel2
# button      button  76.917970              25              13
# screen      screen  70.137533              35              13
# image        image  57.070959               5               8
# number      number  39.189724              26               8
# lesson      lesson  38.288301               6               6
# activity  activity  35.691912               2               5
# simple      simple  29.987956               6               5
# click        click  27.919400             123              10
# console    console  24.179915              14               5
# fine          fine  23.916441               4               4
#
# Completed LLR comparison: Black Girls Code vs Beginner's Code Zone
#
# Top 10 words by LLR score:
#               word    llr_score  count_channel1  count_channel2
# node          node  1331.946574               0             276
# list          list   436.975683              20             114
# linked      linked   299.306731               2              67
# previous  previous   285.546766              20              80
# head          head   249.191114              12              66
# password  password   215.495302               1              48
# next          next   199.857036             146             108
# data          data   199.240122              29              65
# none          none   195.095397               2              45
# current    current   183.356795              25              59
#
# Completed LLR comparison: Black Girls Code vs Coding Workshops for Kids - Online Coding Courses for Kids and Parents
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# onto          onto  419.487583               3             125
# click        click  366.637765             123             211
# scratch    scratch  183.253288              50              99
# sprite      sprite  177.681319              86             118
# block        block  143.529888             250             174
# backdrop  backdrop  131.041463              24              63
# costume    costume  121.013902               2              39
# clicked    clicked  111.114270               5              40
# tool          tool  110.598899              52              73
# apply        apply  107.418955               6              40
#
# Completed LLR comparison: Black Girls Code vs Computer World Kids
#
# Top 10 words by LLR score:
#                 word   llr_score  count_channel1  count_channel2
# moving        moving  449.755135              35              55
# sometimes  sometimes  185.676892              31              26
# ill              ill   87.284131             128              20
# there          there   81.299461             152              20
# time            time   72.422522             196              20
# ming            ming   63.151010               0               7
# enough        enough   58.316999              23              10
# turn            turn   48.317685              43              10
# else            else   47.797345              28               9
# used            used   46.807439              30               9
#
# Completed LLR comparison: Black Girls Code vs Girls Will Code
#
# Top 10 words by LLR score:
#               word   llr_score  count_channel1  count_channel2
# string      string  154.780583               1              50
# player      player  142.496009              49              90
# variable  variable  129.978545              74             100
# move          move  126.341988              86             105
# print        print  106.066297               2              37
# clone        clone   98.371852               0              31
# people      people   94.742443             297               3
# sprite      sprite   94.539727              86              90
# costume    costume   93.068516               2              33
# really      really   91.972043             341               7
#
# Completed LLR comparison: Black Girls Code vs Coding Kids
#
# Top 10 words by LLR score:
#           word   llr_score  count_channel1  count_channel2
# yep        yep  749.822740               6             490
# turtle  turtle  406.101205               0             250
# screen  screen  297.030836              35             291
# people  people  284.746370             297               7
# girl      girl  277.312476             246               0
# file      file  273.205314              20             238
# black    black  232.889715             245               6
# bob        bob  231.976148               1             150
# python  python  229.840262               7             172
# number  number  216.741452              26             214
#
# Completed LLR comparison: Black Girls Code vs Tech With Tim
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# girl      girl  1758.591441             246               1
# black    black  1093.103276             245             253
# woman    woman   749.568743             111               6
# art        art   657.036263             118              46
# love      love   629.170025             152             197
# say        say   564.597815             167           24939
# block    block   484.564529             250            1383
# equal    equal   474.559169              35           12942
# career  career   472.629844             108             117
# people  people   454.678660             297            2155
#
# Completed LLR comparison: Black Girls Code vs Jenny's Lectures CS IT
#
# Top 10 words by LLR score:
#           word    llr_score  count_channel1  count_channel2
# really  really  1203.820015             341             138
# girl      girl  1152.042978             246              15
# people  people  1110.454529             297              95
# lot        lot   749.385292             187              42
# write    write   656.170201              27            5426
# youre    youre   595.268390             252             290
# make      make   588.853063             319             550
# print    print   581.271701               2            3852
# game      game   563.672697             217             206
# look      look   563.081589             182             112
#
# Saved combined LLR comparisons file
# LLR Analysis complete!

# %% [markdown]
# ## Fighting Words
# - [DEF] extension of LLR. uses z-scores to adjust word frequency differences, highlighting over- and under-represented words between two corpora (in other words, highling polarized or distinctive words; FightingWords has historically been used for political speeches, for example). typically used when there is a need to focus on identifying polarized language or specific distinctions in word usage between corpora.
# - Interpretation: so, FightingWords calculate Z-Scores on a 95% confidence interval, corresponding to a Z-Score range of [-1.96,1.96]; any Z-Score outside of that is statistically significant at 95% confidence, where a positive Z-Score is more indicative of Channel A and a negative Z-Score is indicative of Channel B. As a practical example, let's say we were comparing word usage between Black Girls Code versus code.org. If we looked up that specific comparison .csv and looked at the word "black": the Z-Score is +25.37, meaning that the word "Black" is very strongly associated with Black Girls Code in this particular channel comparison.
# - In the context of our data, it would help:
#     - Highlight polarized or distinctive language between different channels
#     - Identifying words that are strongly associated with specific content types
#     - ** Detecting significant vocabulary diferences between different groups of videos **
# - How does this differ from what we've done before (TFs, TFDs, TF-IDFs...)?
#     - Incorporates statistical significance through using z-scores
#     - Accounts for sampling variability in word frequencies
#     - More robust when dealing with varying transcript lengths
# - Implementation: we'd basically need to "borrow" the code from open-source repositories, adapt it for our own purposes, save it as a Python script... like this one (https://github.com/jmhessel/FightingWords) or this one from Myra Cheng, a PhD in CS advised by Dan Jurafsky (https://github.com/myracheng/markedpersonas/blob/main/marked_words.py). ***Our implementation ended up taking from both.***

# %%
# from collections import defaultdict
# from typing import List, Dict

# class BlackGirlsCodeComparison:
#     """Class to perform FightingWords analysis comparing Black Girls Code with other channels"""
    
#     def __init__(self, prior: float = 0.01):
#         """
#         Initialize with smoothing prior
#         Args:
#             prior (float): Smoothing parameter for word frequencies
#         """
#         self.prior = prior
        
#     def process_text(self, text: str) -> List[str]:
#         """
#         Process text to get clean word list
#         Args:
#             text (str): Input text to process
#         Returns:
#             List[str]: List of cleaned words
#         """
#         if isinstance(text, str):
#             # Handle string representation of list
#             if text.startswith('[') and text.endswith(']'):
#                 text = text.strip('[]').replace("'", "").replace(",", " ")
#             return [word.lower() for word in text.split() if word.isalnum()]
#         return []
        
#     def calculate_zscores(self, texts1: List[str], texts2: List[str], 
#                          channel_name: str) -> pd.DataFrame:
#         """
#         Calculate z-scores between two text corpora using Monroe et al.'s method
#         Args:
#             texts1 (List[str]): Black Girls Code texts
#             texts2 (List[str]): Comparison channel texts
#             channel_name (str): Name of channel being compared
#         Returns:
#             pd.DataFrame: DataFrame with word comparison statistics
#         """
#         # Initialize word count dictionaries
#         counts1 = defaultdict(int)  # BGC word counts
#         counts2 = defaultdict(int)  # Other channel word counts
        
#         # Count words in each corpus
#         for text in texts1:
#             for word in self.process_text(text):
#                 counts1[word] += 1
                
#         for text in texts2:
#             for word in self.process_text(text):
#                 counts2[word] += 1
        
#         # Skip if either corpus is empty
#         if not counts1 or not counts2:
#             return pd.DataFrame()
        
#         # Calculate statistics
#         results = []
#         n1 = sum(counts1.values())  # Total words in BGC
#         n2 = sum(counts2.values())  # Total words in other channel
#         vocab = set(counts1.keys()) | set(counts2.keys())
        
#         # Calculate z-scores for each word
#         for word in vocab:
#             # Add smoothing
#             c1 = counts1[word] + self.prior
#             c2 = counts2[word] + self.prior
            
#             # Calculate rates and variance
#             rate1 = c1 / (n1 + len(vocab) * self.prior)
#             rate2 = c2 / (n2 + len(vocab) * self.prior)
#             var = (1/c1) + (1/c2)
            
#             if var > 0:
#                 # Calculate z-score using Monroe et al.'s method
#                 delta = np.log(rate1) - np.log(rate2)
#                 zscore = delta / np.sqrt(var)
                
#                 results.append({
#                     'word': word,
#                     'z_score': zscore,
#                     'bgc_count': counts1[word],
#                     'other_count': counts2[word],
#                     'compared_channel': channel_name
#                 })
        
#         return pd.DataFrame(results) if results else pd.DataFrame()

# def analyze_bgc_comparisons(df: pd.DataFrame) -> Dict[str, pd.DataFrame]:
#     """
#     Analyze Black Girls Code against all other channels
#     Args:
#         df (pd.DataFrame): DataFrame with channel content
#     Returns:
#         Dict[str, pd.DataFrame]: Dictionary of comparison results per channel
#     """
#     # Create output directory
#     output_dir = 'black_girls_code_comparisons'
#     os.makedirs(output_dir, exist_ok=True)
    
#     # Get Black Girls Code texts
#     bgc_texts = df[df['channel_name'] == 'Black Girls Code']['preprocessed_content'].tolist()
#     if not bgc_texts:
#         raise ValueError("No Black Girls Code content found in dataset")
    
#     # Initialize analyzer and results
#     bgc = BlackGirlsCodeComparison()
#     results = {}
#     all_comparisons = []
    
#     # Compare with each channel
#     for channel in df['channel_name'].unique():
#         if channel != 'Black Girls Code':
#             try:
#                 # Get channel texts
#                 other_texts = df[df['channel_name'] == channel]['preprocessed_content'].tolist()
                
#                 # Calculate comparison
#                 comparison = bgc.calculate_zscores(bgc_texts, other_texts, channel)
                
#                 if not comparison.empty:
#                     # Sort by absolute z-score
#                     comparison['abs_z_score'] = comparison['z_score'].abs()
#                     comparison = comparison.sort_values('abs_z_score', ascending=False)
#                     comparison = comparison.drop('abs_z_score', axis=1)
                    
#                     # Save individual comparison
#                     safe_channel = "".join(x for x in channel if x.isalnum() or x in (' ', '-', '_'))
#                     filename = f'BGC_vs_{safe_channel}_comparison.csv'
#                     filepath = os.path.join(output_dir, filename)
#                     comparison.to_csv(filepath, index=False)
                    
#                     results[channel] = comparison
#                     all_comparisons.append(comparison)
                    
#                     # Print progress and top words
#                     print(f"\nCompleted comparison: Black Girls Code vs {channel}")
#                     if len(comparison) > 0:
#                         print("\nTop 10 words distinctive to Black Girls Code:")
#                         print(comparison[comparison['z_score'] > 0].head(10)[['word', 'z_score']])
#                         print(f"\nTop 10 words distinctive to {channel}:")
#                         print(comparison[comparison['z_score'] < 0].head(10)[['word', 'z_score']])
                
#             except Exception as e:
#                 print(f"Error comparing with {channel}: {str(e)}")
#                 continue
    
#     # Save combined results
#     if all_comparisons:
#         combined = pd.concat(all_comparisons, ignore_index=True)
#         combined.to_csv(os.path.join(output_dir, 'all_comparisons.csv'), index=False)
#         print("\nSaved combined comparisons file")
    
#     return results

# def main(df: pd.DataFrame):
#     """
#     Main analysis pipeline
#     Args:
#         df (pd.DataFrame): Input DataFrame with channel content
#     Returns:
#         Dict[str, pd.DataFrame]: Analysis results
#     """
#     # Verify data
#     if df['preprocessed_content'].isna().all():
#         raise ValueError("No valid content found in preprocessed_content column")
    
#     print("Starting Black Girls Code comparisons...")
#     results = analyze_bgc_comparisons(df)
#     print("Analysis complete!")
#     return results

# # Run the analysis
# if __name__ == "__main__":
#     results = main(df_metadata_transcript)
# Out:
# Starting Black Girls Code comparisons...
#
# Completed comparison: Black Girls Code vs Codecademy
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 8514    block  29.256177
# 11731   black  28.496958
# 3565     girl  23.372806
# 1872      art  20.231130
# 7842    woman  19.572805
# 7417     game  18.781732
# 5847   sprite  15.933149
# 4365     love  15.876108
# 7780   circle  15.269409
# 3390    level  14.633201
#
# Top 10 words distinctive to Codecademy:
#           word    z_score
# 6793      data -12.308662
# 6578      kind  -9.538185
# 11730      see  -9.142460
# 5425    number  -8.852147
# 6408       bit  -8.687348
# 12901   little  -7.682166
# 952      might  -7.563243
# 3751      list  -7.523329
# 8965      file  -7.345323
# 585    example  -7.170319
#
# Completed comparison: Black Girls Code vs Coding for kids
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 5003      know  11.941572
# 4403    people  11.850270
# 1008     block   9.649677
# 6474     black   9.379422
# 4109     thank   8.647285
# 6317     think   8.585580
# 3506  question   8.121975
# 6009     youre   7.982978
# 3628     color   7.562573
# 5606     level   7.455544
#
# Top 10 words distinctive to Coding for kids:
#        word    z_score
# 1520    let -20.802854
# 5561    one -18.229596
# 3750     go -13.263067
# 3420    put -12.789935
# 1256    two -12.765554
# 3889  equal -12.715467
# 6223   list -12.117576
# 808    name -11.120874
# 5441  three -10.809295
# 4786   type -10.658576
#
# Completed comparison: Black Girls Code vs Scratch Team
#
# Top 10 words distinctive to Black Girls Code:
#        word    z_score
# 3563   girl  14.042196
# 3907  black  13.906601
# 3414  level   9.874256
# 1829   need   8.936920
# 489    tech   8.113604
# 5651  space   7.995543
# 1877    art   7.865722
# 7542  build   7.655845
# 6373    job   7.654234
# 7392   game   7.583141
#
# Top 10 words distinctive to Scratch Team:
#            word    z_score
# 7365    scratch -20.391765
# 5518    project -16.862111
# 1288       sort -10.384603
# 5165      could -10.328510
# 5850     sprite  -8.728391
# 7648       show  -8.642181
# 6252  character  -8.600971
# 4077       idea  -8.358729
# 1071      click  -8.268016
# 3906        see  -7.725368
#
# Completed comparison: Black Girls Code vs Code.org
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 11638   black  25.392533
# 3477     girl  25.045630
# 10632     add  18.088498
# 7662   circle  15.690756
# 1815      art  15.052689
# 7709   canvas  14.008906
# 5543    space  13.464601
# 503      tech  13.189369
# 7731    woman  12.970545
# 15165    ball  12.653978
#
# Top 10 words distinctive to Code.org:
#             word    z_score
# 14492   computer -16.158427
# 10143    student -13.307942
# 4777     science -12.784714
# 12077     school -11.121547
# 7871     teacher  -9.659810
# 14222         ai  -8.365410
# 7776        hour  -7.890166
# 13853      class  -7.416644
# 2278   education  -6.989378
# 1653      screen  -6.731578
#
# Completed comparison: Black Girls Code vs Khan Academy Computing
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 4582  people  12.417408
# 1048   block  11.646314
# 6653   black  11.537171
# 5161    know  11.330119
# 5964    game  10.270742
# 451       im   9.150010
# 697     love   9.106710
# 618   create   7.922615
# 5013   video   7.614975
# 3178     art   7.613750
#
# Top 10 words distinctive to Khan Academy Computing:
#           word    z_score
# 3322  function -12.840889
# 2494    number -11.114847
# 5511  variable -11.053010
# 1299       use -10.658923
# 5397      page -10.547579
# 6652       see -10.303871
# 1311    inside  -9.965069
# 326       draw  -9.416084
# 1169   element  -9.252893
# 4431   program  -9.248214
#
# Completed comparison: Black Girls Code vs Programiz
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 414       im  24.862087
# 4984    know  20.345240
# 1319  really  19.033971
# 6324   think  18.169030
# 4402  people  16.849334
# 1019   thing  16.434296
# 5787    game  16.200920
# 998    block  15.819153
# 3741      go  15.268797
# 4330   thats  14.963834
#
# Top 10 words distinctive to Programiz:
#           word    z_score
# 2916       ill -26.856115
# 1528       let -20.064774
# 3203  function -18.952294
# 946      value -17.509361
# 5074       say -16.978048
# 2398    number -16.244217
# 780        run -15.953168
# 3887     equal -15.459623
# 5331  variable -15.457891
# 4256   program -14.024810
#
# Completed comparison: Black Girls Code vs Clear Code
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 8734      know  37.412466
# 3403    people  28.038989
# 9490     youre  26.281449
# 4886     black  25.599045
# 796      block  24.251938
# 341         im  23.318570
# 7620  question  22.081577
# 2275       ill  20.948895
# 6550       got  19.699206
# 4784     think  18.012958
#
# Top 10 words distinctive to Clear Code:
#           word    z_score
# 2468      want -26.170097
# 9163       one -19.671065
# 1233       let -16.106500
# 1017    inside -14.905314
# 5306    player -14.781930
# 9044       get -14.329460
# 2325      need -13.295222
# 611        run -13.188621
# 8032       bit -13.009098
# 3336  position -11.844738
#
# Completed comparison: Black Girls Code vs w3schools.com
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 4263    know  10.946472
# 5397   think   7.880279
# 371       im   7.793717
# 887    thing   7.583118
# 3773  people   7.543994
# 5525   black   6.953151
# 1139  really   6.539054
# 3214      go   6.467574
# 2491   would   6.099868
# 1243    time   6.004064
#
# Top 10 words distinctive to w3schools.com:
#             word    z_score
# 968      element -16.096854
# 3119       color -15.932213
# 3970        text -15.321160
# 4464        page -14.257587
# 1489         set -13.324123
# 2440    property -13.285728
# 485   background -12.907458
# 4666       style -11.891201
# 5146        link -11.654088
# 1082         use -11.602590
#
# Completed comparison: Black Girls Code vs KidsCanCode
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 2652    people  20.420917
# 3772     think  19.253429
# 6830      know  19.231123
# 593      block  19.188268
# 3851     black  18.804876
# 5958  question  14.231645
# 786     really  12.741557
# 4313      love  11.796614
# 6517      code  11.732846
# 1614     today  11.629858
#
# Top 10 words distinctive to KidsCanCode:
#         word    z_score
# 1034     set -14.462288
# 4182  player -14.028804
# 1921    want -13.936070
# 3850     see -12.589471
# 1784    need -11.896281
# 4983  little -11.355532
# 1662  screen -10.735988
# 53      move -10.376873
# 7166     one -10.094350
# 5735  sprite  -9.353560
#
# Completed comparison: Black Girls Code vs Girls Who Code
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 4462     black  14.422573
# 1127       let  13.401550
# 3299       add  12.918323
# 6979     color  11.276796
# 1247     click  10.410451
# 8393      game  10.367020
# 2154       art  10.284146
# 725      block  10.236362
# 4937    create   9.714264
# 6702  function   9.501536
#
# Top 10 words distinctive to Girls Who Code:
#           word    z_score
# 7893      know -11.339589
# 8630   company -10.907255
# 3557   college  -9.014710
# 6910  question  -8.707289
# 4364     think  -8.653369
# 2750   student  -8.382497
# 7269       job  -8.328733
# 7469      kind  -8.064835
# 958     really  -7.397884
# 8563     youre  -7.378005
#
# Completed comparison: Black Girls Code vs freeCodeCamp.org
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 23990    girl  62.414774
# 53948   black  51.917351
# 29344   woman  43.584996
# 2307      art  38.360960
# 27919  career  35.465441
# 39960    tech  33.423832
# 5380     love  33.145012
# 66904   thank  32.470525
# 10537   block  31.435336
# 35280   young  29.328034
#
# Top 10 words distinctive to freeCodeCamp.org:
#          word    z_score
# 50311     let -14.938057
# 73552     see -11.712931
# 28031    data -10.922494
# 8753      say -10.897922
# 50459    file  -9.944330
# 14556    user  -8.974865
# 30360     use  -8.906117
# 69396   value  -8.769723
# 46065  number  -8.515974
# 17597   equal  -8.402071
#
# Completed comparison: Black Girls Code vs LearnCode.academy
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 4136     black  17.580479
# 655      block  17.397527
# 4040     think  17.295603
# 7397      know  13.349509
# 6460  question  13.189867
# 4641      love  13.046731
# 6853     thank  12.499168
# 6986         u  11.609447
# 7121    career  11.474665
# 5988     space  11.428380
#
# Top 10 words distinctive to LearnCode.academy:
#        word    z_score
# 2447     go -20.946754
# 1008    let -17.399406
# 6990  thats -13.673195
# 6984   kind -10.931243
# 514     run -10.817251
# 1146   file -10.076437
# 7537   page  -9.863585
# 2956  ahead  -9.397628
# 7455    say  -8.832164
# 7655    get  -8.648714
#
# Completed comparison: Black Girls Code vs Code Monkey
#
# Top 10 words distinctive to Black Girls Code:
#             word    z_score
# 10275      block  36.712488
# 14292      black  36.587689
# 18141       know  34.312663
# 17676          u  27.320125
# 12810     people  24.683004
# 593         tech  23.703009
# 9584   community  22.972955
# 11515      today  22.267768
# 8054      career  22.115790
# 5308        love  21.644500
#
# Top 10 words distinctive to Code Monkey:
#            word    z_score
# 10701       let -21.084951
# 8903       game -17.814912
# 8764        one -16.827022
# 11632    object -12.435883
# 14725    player -10.540266
# 14451      nice -10.414741
# 14291       see -10.091233
# 3171   position  -9.665201
# 1248     system  -9.452406
# 12284        go  -9.415933
#
# Completed comparison: Black Girls Code vs Corey Schafer
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 722    block  23.759302
# 4433   black  21.784924
# 7960    know  21.115176
# 958   really  18.402220
# 4983    love  17.243499
# 3881   level  16.883755
# 3092  people  16.796754
# 8506    game  16.235992
# 2174     art  16.101741
# 4419   sound  15.864412
#
# Top 10 words distinctive to Corey Schafer:
#         word    z_score
# 4431     see -18.090686
# 564      run -14.690114
# 1114     let -14.259285
# 1259    file -13.922766
# 8031     say -13.369871
# 7862   video -13.232487
# 7760    data -11.010379
# 4268    list -10.658949
# 7210   equal -10.599435
# 4012  within -10.593897
#
# Completed comparison: Black Girls Code vs TechWorld with Nana
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 7592    know  24.173334
# 4166   think  23.098350
# 905   really  22.818867
# 2936  people  22.542693
# 675    block  21.069167
# 6764   there  16.268393
# 3149     add  15.883124
# 7024   thank  15.758865
# 8114    game  15.282706
# 4765    love  15.124489
#
# Top 10 words distinctive to TechWorld with Nana:
#              word    z_score
# 1198         file -13.073431
# 8022        using -11.881478
# 7390         data -11.291523
# 631       example -10.973640
# 858           use -10.806615
# 4257          see -10.742050
# 4233         user -10.476810
# 6420  application -10.017705
# 538           run  -9.833148
# 2606      service  -9.815847
#
# Completed comparison: Black Girls Code vs Clever Programmer
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 18135    girl  46.002299
# 11099   black  41.317957
# 8084    block  41.280509
# 1762      art  31.763180
# 22054   woman  27.067865
# 462      tech  26.967651
# 7063     game  26.385623
# 21004  career  25.383245
# 7410   circle  24.377253
# 7443   canvas  23.482365
#
# Top 10 words distinctive to Clever Programmer:
#          word    z_score
# 24198      go -18.829996
# 8412      let -18.256875
# 13193     guy -17.327186
# 6728      say -15.195149
# 6293    thats -13.565283
# 10105   ahead -13.322762
# 25677     see -11.028068
# 25796    nice  -8.491808
# 22083  pretty  -8.394158
# 4483      app  -8.237920
#
# Completed comparison: Black Girls Code vs CodeBeauty
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 5575    know  24.469047
# 7050   think  23.474590
# 4853   thats  22.318805
# 6681   youre  19.544925
# 4939  people  19.525838
# 6445    game  19.463566
# 4216      go  18.164180
# 1135   block  17.397034
# 6554    girl  16.343700
# 749     love  16.206737
#
# Top 10 words distinctive to CodeBeauty:
#           word    z_score
# 5667       say -20.558986
# 1722       let -17.479946
# 3595  function -16.471502
# 2702    number -15.608984
# 5423     video -14.157331
# 4771   program -13.998189
# 1077     value -13.854180
# 5938  variable -13.772369
# 7172      user -12.781939
# 5451     write -12.317300
#
# Completed comparison: Black Girls Code vs Coding with John
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 455         im  18.379179
# 4781    people  16.579525
# 1084     block  15.434102
# 5417      know  12.194807
# 713       love  11.967138
# 6251      game  11.913574
# 4454     thank  11.652948
# 3798  question  11.024940
# 3017     space  10.880497
# 6802     think  10.566812
#
# Top 10 words distinctive to Coding with John:
#         word    z_score
# 2588  number -15.159264
# 1392    call -11.789588
# 3848   class -11.667727
# 4212   equal -11.607700
# 5135     cat -11.130574
# 870     name -10.943401
# 2380    loop -10.608257
# 6703    list -10.559534
# 859      run -10.521634
# 3069  object  -9.737394
#
# Completed comparison: Black Girls Code vs griffpatch
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 8541      know  28.218325
# 3268    people  23.058552
# 4748     black  20.892330
# 9271     youre  20.728165
# 4646     think  16.800289
# 7424  question  15.574419
# 324         im  15.388959
# 7866     thank  14.504300
# 8019      kind  13.776691
# 8105      code  13.717840
#
# Top 10 words distinctive to griffpatch:
#          word    z_score
# 7151   sprite -16.798585
# 5145   player -14.164212
# 4290   script -14.045878
# 1280      set -13.505710
# 4134    level -12.198344
# 2011      new -11.286216
# 7842        x -10.575214
# 9066  scratch -10.188685
# 67       move -10.130770
# 2046   screen -10.115670
#
# Completed comparison: Black Girls Code vs My CS
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 11494   black  29.046328
# 7257     game  28.246242
# 8302    block  27.732652
# 4262     love  23.344554
# 6314    thank  22.701300
# 3486     girl  22.355988
# 10333  people  22.304669
# 6498     code  21.074740
# 1827      art  20.691763
# 14448    know  20.239162
#
# Top 10 words distinctive to My CS:
#          word    z_score
# 6298        x -16.244874
# 7141      one -12.975766
# 13828   equal -12.889197
# 753       two -12.725962
# 6642     data -12.652121
# 5286   number -12.060272
# 8270    value -11.815632
# 9223     plus -11.251699
# 1546     zero  -9.817427
# 14697   three  -9.663806
#
# Completed comparison: Black Girls Code vs CodingNepal
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 3451  people  5.254462
# 1193     let  4.783379
# 805    thing  4.733148
# 4923   think  4.699655
# 4292    work  4.150118
# 1038  really  4.100850
# 2939   first  3.982116
# 3400   thats  3.952713
# 461   create  3.868343
# 3963     say  3.599432
#
# Top 10 words distinctive to CodingNepal:
#          word    z_score
# 1982  foreign -26.887102
# 2186    still -23.124527
# 3222    thank -22.396164
# 3899     know -20.186954
# 5109     tell -13.767072
# 4759    never -12.812507
# 130      came -12.796367
# 314      turn -12.736920
# 1178  nothing -12.682069
# 1135     time -12.551776
#
# Completed comparison: Black Girls Code vs AlvinBlox
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 2655    people  21.983740
# 3851     black  20.178839
# 3769     think  18.677964
# 824     really  17.493698
# 6808      know  16.492270
# 6317     thank  16.371578
# 626      block  16.246473
# 5962  question  15.634939
# 3366     level  14.060717
# 5548     space  13.587937
#
# Top 10 words distinctive to AlvinBlox:
#           word    z_score
# 4194    player -18.709448
# 3484    script -16.031644
# 6856       say -15.940469
# 7278      game -14.742764
# 5078      part -13.680511
# 594      value -13.651548
# 1075       set -13.167782
# 6624      data -12.904751
# 6845      weve -12.899009
# 5776  function -12.658763
#
# Completed comparison: Black Girls Code vs thenewboston
#
# Top 10 words distinctive to Black Girls Code:
#             word    z_score
# 10511      black  30.805319
# 3249        girl  28.075642
# 6584        game  25.007698
# 9447      people  24.942662
# 7565       block  24.696812
# 3919        love  22.850887
# 1694         art  20.424402
# 7058   community  19.862237
# 442         tech  19.765781
# 3452       think  19.257778
#
# Top 10 words distinctive to thenewboston:
#            word    z_score
# 9067         go -16.822472
# 9532      ahead -16.587641
# 7873        let -14.074931
# 12630     equal -12.517457
# 6235        say -12.373839
# 7987       file -10.640053
# 13116      type  -9.949688
# 4004       name  -9.869242
# 3133   whenever  -9.638155
# 10486      user  -9.480827
#
# Completed comparison: Black Girls Code vs CS Dojo
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 674    block  16.494592
# 7806    game  14.996482
# 4593    love  12.859675
# 3750    girl  12.529597
# 6482   color  12.015245
# 3055     add  11.027872
# 3588   level  11.009281
# 7061  career  10.825663
# 4110   black  10.708323
# 3705    play  10.032039
#
# Top 10 words distinctive to CS Dojo:
#          word    z_score
# 5729   number -11.684121
# 621   example -10.977141
# 1081  problem -10.967095
# 836       two -10.086199
# 7339     know  -9.999542
# 7141     data  -9.779722
# 7682      one  -9.349864
# 7389      say  -8.966285
# 5576     case  -8.766194
# 6650    equal  -8.440479
#
# Completed comparison: Black Girls Code vs CodeWithChris
#
# Top 10 words distinctive to Black Girls Code:
#             word    z_score
# 6028       black  30.725023
# 992        block  26.565040
# 6746        love  24.398611
# 4182      people  23.201400
# 11456       game  21.982716
# 9968       thank  21.034289
# 2916         art  20.884075
# 5509        girl  20.820589
# 10348     career  19.732442
# 107    community  19.520622
#
# Top 10 words distinctive to CodeWithChris:
#            word    z_score
# 1522        let -14.875844
# 7292        app -13.618121
# 10457      data -13.341479
# 6027        see -12.252358
# 9384       view -10.331555
# 1543     button -10.255413
# 2738   property -10.080108
# 5994       user  -9.733505
# 10530      type  -9.426092
# 8537    project  -9.394584
#
# Completed comparison: Black Girls Code vs Programming with Mosh
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 8713    know  30.224176
# 4815   think  25.158898
# 3386  people  24.993691
# 9288    game  22.924097
# 1059  really  22.922465
# 4916   black  21.361982
# 811    thing  19.424408
# 791    block  19.342878
# 5518    love  19.254495
# 7771   there  19.029885
#
# Top 10 words distinctive to Programming with Mosh:
#           word    z_score
# 1229       let -15.403059
# 1004       use -13.577874
# 2195    object -13.260555
# 1489    course -13.097052
# 7381  function -12.925606
# 8558      type -12.337076
# 1027      call -10.647038
# 6820    number -10.554584
# 1382      file -10.541099
# 7653     class -10.267200
#
# Completed comparison: Black Girls Code vs Brackeys
#
# Top 10 words distinctive to Black Girls Code:
#             word    z_score
# 13731       know  34.872845
# 7848       block  29.937954
# 10858      black  29.267455
# 9777      people  27.311663
# 4086        love  21.313837
# 5967       thank  20.098394
# 468         tech  19.618917
# 7343   community  18.881434
# 1730         art  18.489478
# 6149        code  18.383382
#
# Top 10 words distinctive to Brackeys:
#          word    z_score
# 8167      let -16.917948
# 9393       go -14.913184
# 10857     see -13.007808
# 11174  player -12.509633
# 9851    ahead -11.404052
# 1016      set -10.786488
# 8897   object -10.784219
# 6849     game -10.625875
# 1096   course -10.465920
# 746      call -10.189274
#
# Completed comparison: Black Girls Code vs Bro Code
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 8637    know  43.689066
# 3354  people  32.564305
# 4870   black  31.789470
# 999   really  29.601303
# 765    block  25.043866
# 4769   think  24.986870
# 5480    love  21.686407
# 2361     art  21.415845
# 4858   sound  20.603467
# 4484     lot  20.545717
#
# Top 10 words distinctive to Bro Code:
#           word    z_score
# 1173       let -22.909062
# 1339       set -16.199715
# 5588      name -15.465472
# 7836     equal -15.170429
# 7342  function -14.983243
# 4405    within -13.858578
# 8477      type -13.058370
# 1187    button -12.453975
# 6767    number -12.187925
# 2300      need -12.055669
#
# Completed comparison: Black Girls Code vs The Coding Train
#
# Top 10 words distinctive to Black Girls Code:
#               word    z_score
# 9360         block  44.655761
# 21311         girl  43.286376
# 12943        black  39.399714
# 25931        woman  31.189362
# 511           tech  31.033768
# 6432        sprite  26.635933
# 13150  opportunity  25.907222
# 24705       career  25.632806
# 2026           art  25.273256
# 22259   technology  24.024049
#
# Top 10 words distinctive to The Coding Train:
#          word    z_score
# 267        im -23.071884
# 9726      let -15.490234
# 5641    could -13.549880
# 30346     see -12.038787
# 7723      say -11.833693
# 7562    video  -9.747864
# 5952   number  -9.111558
# 27394    sort  -8.910249
# 22921    look  -8.732111
# 15643   equal  -8.309166
#
# Completed comparison: Black Girls Code vs mycodeschool
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 5625    know  22.119210
# 7082   think  17.371719
# 464       im  17.024168
# 1502  really  16.706858
# 4905   thats  16.479134
# 4985  people  15.086073
# 5336     add  14.215000
# 6479    game  13.957550
# 6726   youre  13.577850
# 122     dont  12.340111
#
# Top 10 words distinctive to mycodeschool:
#           word    z_score
# 3603  function -17.368758
# 6981      list -13.917217
# 5992  variable -13.844658
# 1459      call -13.604308
# 7111    memory -13.191980
# 2690    number -12.958526
# 2705   address -12.758060
# 1262   element -12.599893
# 1077     value -12.298797
# 5290      data -11.824518
#
# Completed comparison: Black Girls Code vs Programming For Beginners
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 5250    know  39.535780
# 452       im  36.692474
# 4657  people  26.123175
# 6266   youre  25.637265
# 3960      go  24.935972
# 1094   thing  24.564267
# 6738   black  22.659142
# 6180     lot  21.578823
# 6043    game  21.430469
# 3929   there  20.092574
#
# Top 10 words distinctive to Programming For Beginners:
#         word    z_score
# 3931     guy -24.454960
# 1631     let -22.759500
# 6737     see -18.858863
# 5337     say -17.897318
# 1026   value -16.946382
# 1359  inside -16.823237
# 1858    file -16.151172
# 2554  number -15.347940
# 4626    save -15.204255
# 1895     try -14.214338
#
# Completed comparison: Black Girls Code vs Code With Conner
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 4536    know  11.773331
# 4011  people   9.969042
# 5742   think   9.578176
# 909    block   9.161704
# 1205  really   8.244498
# 5878   black   8.242014
# 5252    game   7.956061
# 3747   thank   7.142313
# 595     love   7.055872
# 4302     add   6.771621
#
# Top 10 words distinctive to Code With Conner:
#            word    z_score
# 867       value -18.397924
# 2008       loop -11.994027
# 2175     number -10.896946
# 2336       zero -10.630729
# 1063  statement  -9.909748
# 721         run  -9.872081
# 2910   function  -9.552078
# 4851   variable  -9.499551
# 4052       code  -9.430606
# 5655       list  -9.370863
#
# Completed comparison: Black Girls Code vs Learn Computer Programming
#
# Top 10 words distinctive to Black Girls Code:
#        word    z_score
# 4895   know  16.998202
# 417      im  14.982716
# 3130   want  14.678465
# 2229   make  13.662618
# 6188  think  13.336910
# 3679     go  12.431257
# 1014  thing  12.118419
# 4251  thats  11.822536
# 994   block  10.571217
# 2839  would  10.539699
#
# Top 10 words distinctive to Learn Computer Programming:
#         word    z_score
# 2120    give -18.853505
# 1515     let -18.050751
# 4240       u -17.941243
# 3815   equal -17.541141
# 943    value -17.540014
# 2335  number -16.450641
# 2496    plus -14.666652
# 6332     see -13.337361
# 4699    type -12.964034
# 2161    loop -12.693638
#
# Completed comparison: Black Girls Code vs First Code Academy
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 4979      know  20.234144
# 6318     think  15.045877
# 1307    really  14.889688
# 6464     black  13.217638
# 4413    people  13.108043
# 5923       lot  11.139829
# 6004     youre  10.363790
# 5499      work   9.413650
# 3532  question   8.827694
# 2093       got   8.760919
#
# Top 10 words distinctive to First Code Academy:
#          word    z_score
# 423        im -18.999010
# 1703    click -18.877746
# 5790   change -14.223887
# 2612     next -12.277260
# 1532   button -11.063856
# 2571  project -10.337150
# 5554      one -10.217879
# 993     block -10.168130
# 3448      put -10.043972
# 1243      two  -9.935595
#
# Completed comparison: Black Girls Code vs STEMinGames - Beginner Programming
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 3974      know  10.338058
# 3518    people   7.243994
# 5031     think   6.986567
# 5148     black   6.567942
# 4678      girl   6.523269
# 344         im   6.071749
# 1067    really   5.989818
# 532       love   5.007506
# 2234     space   5.004205
# 2828  question   4.971558
#
# Top 10 words distinctive to STEMinGames - Beginner Programming:
#            word    z_score
# 1832       make -16.160202
# 3082  character -13.090984
# 3011         go -13.080095
# 1376      click -12.639505
# 4744      green -12.435278
# 4570    scratch -12.184842
# 1227        let -11.696820
# 2176       flag -11.164951
# 2383       need -10.900737
# 4615     change -10.478057
#
# Completed comparison: Black Girls Code vs Coding with Mat
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 3479  people  3.812037
# 4974   think  3.788582
# 1044  really  3.488476
# 791    block  3.471503
# 3729     add  3.370304
# 5091   black  3.135552
# 1140    time  3.118620
# 438     also  3.042954
# 3415       u  3.017822
# 4553    game  3.013044
#
# Top 10 words distinctive to Coding with Mat:
#          word    z_score
# 3357  program -14.091165
# 2021  project -13.481085
# 2018     plus -13.199650
# 1374     file -12.830691
# 1993        c -12.235219
# 1284     line -11.011373
# 2932     open  -9.432678
# 2190   simple  -8.987961
# 1722     case  -8.611261
# 752     value  -8.559448
#
# Completed comparison: Black Girls Code vs Hackingtons Code School
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 4393      know  11.009498
# 5559     think   8.654375
# 3898    people   8.140923
# 5683     black   7.441135
# 573       love   6.147061
# 3112  question   6.069249
# 3625     thank   5.942430
# 1161    really   5.401387
# 5202       lot   5.203967
# 489       also   5.198543
#
# Top 10 words distinctive to Hackingtons Code School:
#            word    z_score
# 3321         go -19.362554
# 1340        let -17.703674
# 5081       game -16.049078
# 4011      ahead -11.791603
# 2785     sprite -10.739142
# 401      player -10.662156
# 374          im  -9.705188
# 80    animation  -9.042384
# 1501      click  -9.027427
# 1521        set  -9.006600
#
# Completed comparison: Black Girls Code vs The BlackFemale Engineer
#
# Top 10 words distinctive to Black Girls Code:
#           word   z_score
# 4999     black  2.794900
# 328         im  2.713018
# 3665       add  2.569580
# 4570       lot  2.474154
# 4466      game  2.406125
# 3192     thank  2.245795
# 3420    people  2.119951
# 2743  question  2.052106
# 4330     level  2.017333
# 2251      able  1.878243
#
# Top 10 words distinctive to The BlackFemale Engineer:
#           word    z_score
# 971        app -10.200155
# 725    example  -8.461713
# 1741  language  -8.271880
# 4650      link  -7.492791
# 506    content  -7.295144
# 1064  learning  -7.096931
# 3005   provide  -7.082971
# 2299     table  -6.957686
# 1980   project  -6.876830
# 4998       see  -6.728823
#
# Completed comparison: Black Girls Code vs Codingal Education
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4100     get  1.779684
# 4806   think  1.773356
# 3356  people  1.707785
# 4568   youre  1.542482
# 320       im  1.441697
# 4182    work  1.237033
# 3798    know  1.227490
# 444   create  1.098138
# 92      dont  1.045662
# 2844   there  1.034096
#
# Top 10 words distinctive to Codingal Education:
#              word    z_score
# 2222          ill -21.267053
# 1948      project -11.057657
# 3805          lab  -7.814028
# 2409       sprite  -7.521326
# 2948        event  -6.914698
# 1300        click  -6.416022
# 2857       moving  -6.399932
# 3615        shark  -6.328919
# 1720          eat  -6.230853
# 1006  competition  -6.230853
#
# Completed comparison: Black Girls Code vs ShawCode
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4160    know  9.103957
# 348       im  7.302945
# 5235   think  7.035845
# 3683  people  6.405133
# 838    block  6.254499
# 4983   youre  6.167778
# 4573    work  5.399367
# 1520    look  5.248145
# 3615       u  4.994444
# 4796    game  4.918279
#
# Top 10 words distinctive to ShawCode:
#           word    z_score
# 3248     equal -17.734074
# 4426  variable -16.522414
# 664        run -13.721903
# 5157      list -13.147596
# 1456      file -12.457418
# 4046     video -12.184192
# 3758     hello -12.160288
# 1995    number -11.669420
# 4482       get -11.521177
# 441       true -11.409028
#
# Completed comparison: Black Girls Code vs Low Level Learning
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 364       im  5.562835
# 4205    know  5.562757
# 3735  people  5.124605
# 5303   think  5.093341
# 866    block  4.834465
# 2704    want  4.736255
# 4863  change  3.846785
# 5429   black  3.773694
# 1139  really  3.685427
# 860    start  3.470809
#
# Top 10 words distinctive to Low Level Learning:
#           word    z_score
# 3601   program -13.393026
# 2715  function -13.163595
# 3771      code -12.763884
# 2142         c -11.400931
# 4038      type -11.196279
# 1486      file -10.862847
# 823      value -10.778382
# 686        run -10.116377
# 808    example  -9.877244
# 2746    return  -9.545102
#
# Completed comparison: Black Girls Code vs ProgrammingKnowledge
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 12366  people  46.366153
# 10168  really  44.255640
# 13762   black  40.544266
# 8774    youre  37.594518
# 13394     lot  31.691040
# 4478    think  31.028969
# 17306    know  30.913673
# 5118     love  29.207330
# 9926    block  28.790837
# 2184      art  27.221142
#
# Top 10 words distinctive to ProgrammingKnowledge:
#          word    z_score
# 13760     see -17.958959
# 9883    value -15.226730
# 10322     let -15.213344
# 5234     name -14.493181
# 10466    file -13.742802
# 10112     use -13.701117
# 12680   write -12.882139
# 1566     give -11.881127
# 9759      run -11.609353
# 930    inside -11.486114
#
# Completed comparison: Black Girls Code vs Cave of Programming
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 7241      know  20.210678
# 2819    people  19.045620
# 7719      game  17.681153
# 619      block  17.269779
# 4084     black  14.579653
# 6348  question  14.024871
# 6718     thank  13.655065
# 3582     level  13.241111
# 3037       add  12.541177
# 4075     sound  11.975736
#
# Top 10 words distinctive to Cave of Programming:
#           word    z_score
# 984        let -17.978685
# 7294       say -15.930306
# 583      value -14.860138
# 479        run -13.372846
# 6577     equal -13.061096
# 6805   program -12.859484
# 7279      weve -12.510099
# 3426  variable -12.417953
# 7116      type -12.379354
# 5487       got -12.370497
#
# Completed comparison: Black Girls Code vs MrBrownCS
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4167  people  9.739381
# 942    block  8.927662
# 408       im  8.829039
# 4701    know  8.273948
# 5444    game  7.510134
# 5949   think  7.045663
# 559   create  6.981884
# 3444   color  6.855279
# 3885   thank  6.798235
# 1608   click  6.321905
#
# Top 10 words distinctive to MrBrownCS:
#           word    z_score
# 2251    number -12.996430
# 5862      list -11.846633
# 3821       bit -11.276729
# 1536      line -11.117960
# 1865     could -10.316121
# 6053      user -10.090460
# 1180       two -10.084126
# 894      value  -9.998241
# 5022  variable  -9.736148
# 2073      loop  -9.542638
#
# Completed comparison: Black Girls Code vs CS50 Made Easy with Rahul
#
# Top 10 words distinctive to Black Girls Code:
#            word   z_score
# 352          im  9.005385
# 1097     really  8.192139
# 5185      think  7.898335
# 3625     people  7.644030
# 4936      youre  6.761335
# 4096       know  6.691176
# 4856        lot  6.062850
# 487      create  5.628177
# 2807  different  5.502416
# 3381      thank  5.407126
#
# Top 10 words distinctive to CS50 Made Easy with Rahul:
#         word    z_score
# 1261     let -19.231785
# 2459    need -16.897946
# 1975  number -13.355632
# 1708    sort -12.269881
# 5275    user -12.025858
# 1820    loop -11.922080
# 2108    plus -11.661169
# 1348    line -11.294226
# 3200   equal -11.036571
# 1043     two -10.366695
#
# Completed comparison: Black Girls Code vs Coding is for girls
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 364       im  9.296891
# 4282    know  7.523850
# 1149  really  7.395673
# 3721   thats  7.051292
# 4626     get  6.880362
# 5404   think  6.470426
# 5136   youre  6.444326
# 3774  people  6.389556
# 866    block  5.655555
# 5063     lot  5.636093
#
# Top 10 words distinctive to Coding is for girls:
#           word    z_score
# 1508      file -14.917266
# 4093      type -14.474127
# 687       name -14.430606
# 2073    number -12.696242
# 2771  function -12.307351
# 3624    python -12.122760
# 273     answer -12.084761
# 820      value -12.079630
# 3977      text -11.923348
# 1322       let -11.712546
#
# Completed comparison: Black Girls Code vs CodeMonkey - Coding Games for Kids
#
# Top 10 words distinctive to Black Girls Code:
#            word    z_score
# 2701     people  15.858353
# 3567       girl  14.041824
# 3899      black  13.288260
# 633       block  13.045651
# 6111      color  12.292661
# 5624      space  11.736181
# 2889        add  11.469703
# 1876        art  10.941460
# 75    community  10.744817
# 6682     career  10.721867
#
# Top 10 words distinctive to CodeMonkey - Coding Games for Kids:
#            word    z_score
# 2415    student -16.839899
# 6618       code -16.458100
# 1198     course -15.148737
# 175      coding -14.270174
# 7001  challenge -13.655998
# 3898        see -12.888340
# 100     teacher -11.043413
# 2133  classroom  -9.370307
# 6553       kind  -9.125338
# 6495     lesson  -8.666723
#
# Completed comparison: Black Girls Code vs Kids Coding Playground
#
# Top 10 words distinctive to Black Girls Code:
#           word    z_score
# 2951    people  25.862051
# 4239     black  21.879507
# 3879      girl  21.162094
# 7596      know  19.347839
# 892     really  17.064227
# 3901       lot  16.682958
# 6618  question  15.015071
# 6228      able  14.944296
# 4736      love  14.782735
# 2017       art  14.239256
#
# Top 10 words distinctive to Kids Coding Playground:
#         word    z_score
# 7994     one -21.337309
# 1041     let -19.042753
# 2498      go -15.647858
# 1170     set -14.915343
# 2278     put -14.878885
# 4238     see -14.649108
# 8428    show -11.926452
# 849      two -11.794784
# 4606  player -11.761820
# 5530    back -11.676332
#
# Completed comparison: Black Girls Code vs Kids for Code
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4044    know  8.636121
# 1079  really  6.783265
# 3578  people  6.279995
# 822    block  5.910080
# 5250   black  5.322231
# 5123   think  5.190218
# 4688    game  5.108970
# 4800     lot  4.717250
# 3334   thank  4.226562
# 543     love  3.707270
#
# Top 10 words distinctive to Kids for Code:
#           word    z_score
# 3148     equal -15.053710
# 4318  variable -13.437577
# 5046      list -12.897558
# 1036    inside -12.124427
# 1804      word -11.866812
# 1778      loop -11.537783
# 1324      line -11.468177
# 2066      plus -11.076090
# 2899       tag -10.961052
# 660       name -10.831430
#
# Completed comparison: Black Girls Code vs Kodable
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 1055   block  12.301785
# 4571  people  11.953557
# 4897     add  10.102752
# 1609     let   8.839249
# 3194     art   8.815306
# 6653   sound   8.081758
# 842     tech   8.070700
# 4732  career   8.060575
# 6695   woman   7.992376
# 2904   space   7.939832
#
# Top 10 words distinctive to Kodable:
#           word    z_score
# 4119   student -16.614382
# 269     coding -13.369431
# 4777  computer -11.901631
# 3723     class -11.830903
# 4615      code -10.897331
# 162    teacher -10.502528
# 887        kid -10.338089
# 4410    lesson -10.149288
# 11        hour  -9.970744
# 6703    theyre  -9.602209
#
# Completed comparison: Black Girls Code vs GIRLS CODE TOO!
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4215    know  7.232699
# 1123  really  6.314887
# 5326   think  6.149356
# 3762    code  5.923133
# 3726  people  5.546800
# 854    block  5.471508
# 5064   youre  5.257695
# 4992     lot  4.968962
# 4955    girl  4.841275
# 2460   would  4.776464
#
# Top 10 words distinctive to GIRLS CODE TOO!:
#           word    z_score
# 3286     equal -16.439138
# 4499  variable -16.366573
# 3836     ahead -15.265108
# 1297       let -15.172493
# 4290       say -13.942587
# 3180        go -13.809820
# 1479      file -13.533508
# 683       name -12.353413
# 3238     email -12.119221
# 4409      page -12.090084
#
# Completed comparison: Black Girls Code vs Kidicode Ninja: Coding for Beginners and Kids
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 4138    know  12.555971
# 5248   think   9.131699
# 3663  people   8.271188
# 1101  really   8.134483
# 5367   black   7.896334
# 4983   youre   7.645964
# 3608   thats   7.585965
# 834    block   6.862916
# 3597       u   6.848446
# 4476     get   6.555116
#
# Top 10 words distinctive to Kidicode Ninja: Coding for Beginners and Kids:
#           word    z_score
# 1269       let -19.586372
# 353         im -17.687841
# 4210       say -16.215850
# 4612       one -15.850037
# 3128        go -14.848153
# 5366       see -13.787887
# 2656      want -11.761877
# 4036     write -11.088718
# 828      start -10.871548
# 2372  backdrop -10.496002
#
# Completed comparison: Black Girls Code vs GirlsCodeIt
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 577    block  14.960531
# 3342    girl  14.242697
# 3658   black  13.816566
# 6499    know  13.330874
# 6941    game  12.476298
# 2527  people  12.049146
# 3193   level  10.522990
# 6265  career   9.937133
# 447     tech   9.932674
# 6023   thank   9.864900
#
# Top 10 words distinctive to GirlsCodeIt:
#           word    z_score
# 3049  variable -12.594478
# 5068    number -12.380194
# 5885     equal -12.104451
# 5700     class -10.977270
# 538    example -10.728256
# 545      value -10.519469
# 6330      data -10.447819
# 728        two -10.023558
# 1020      file  -9.863228
# 4182      name  -9.812807
#
# Completed comparison: Black Girls Code vs Easy Codes for Kids
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 4134    know  10.109515
# 3660  people   7.413727
# 4973   youre   6.665236
# 474     also   6.251968
# 5231   think   6.141571
# 1104  really   6.062810
# 2430   would   5.914298
# 4897     lot   5.578343
# 4554    work   5.477528
# 3410   thank   5.326166
#
# Top 10 words distinctive to Easy Codes for Kids:
#           word    z_score
# 3126        go -27.870669
# 1275       let -24.812460
# 1533    little -19.448972
# 3771     ahead -18.409765
# 3355       bit -11.004961
# 358         im -10.535816
# 1425     click -10.411237
# 3716   picture -10.173872
# 2654  negative  -9.787783
# 2635    sprite  -9.770208
#
# Completed comparison: Black Girls Code vs Coding With Kids
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 6955    know  21.624790
# 1947    want  17.453842
# 2682  people  16.783711
# 818   really  16.590027
# 3885   black  15.266079
# 3538    girl  12.919780
# 650    thing  12.586185
# 4335    love  12.102181
# 5690   would  12.015587
# 5207    sure  10.449995
#
# Top 10 words distinctive to Coding With Kids:
#         word    z_score
# 7306     one -20.526585
# 777      two -17.660750
# 945      let -14.741393
# 56      move -13.989336
# 5392  number -12.688772
# 6302   equal -12.438706
# 897     time -12.175198
# 7227   three -11.973774
# 6202   first -11.580726
# 6191   there -11.054255
#
# Completed comparison: Black Girls Code vs Programming Kids
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4054    know  8.675854
# 5264   black  5.718413
# 3577  people  5.573335
# 4779    girl  5.469302
# 3611    code  5.255254
# 2412    need  4.979932
# 4817     lot  4.953434
# 4889   youre  4.835656
# 833    thing  4.822636
# 4705    game  4.683340
#
# Top 10 words distinctive to Programming Kids:
#         word    z_score
# 1234     let -15.770331
# 3884    type -15.547314
# 654     name -14.191491
# 646      run -12.182844
# 3939   video -12.169780
# 2361     ill -11.958483
# 3431  python -11.908251
# 5065    list -11.875215
# 3032     guy -11.824334
# 4368   enter -11.545412
#
# Completed comparison: Black Girls Code vs Kids Coding Club
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 321       im  1.412736
# 781    thing  0.839441
# 3381    code  0.767654
# 764    block  0.690353
# 3783    know  0.617716
# 2435    want  0.597834
# 2866      go  0.565962
# 1011  really  0.561376
# 1734    make  0.554707
# 4087     get  0.554707
#
# Top 10 words distinctive to Kids Coding Club:
#           word    z_score
# 1170    button -12.198099
# 2105    screen -11.805895
# 4298     image  -9.291586
# 1819    number  -9.021320
# 3221    lesson  -8.361051
# 2113    simple  -7.671850
# 2413   console  -7.290096
# 1299     click  -7.042008
# 2806   welcome  -7.034776
# 643   activity  -6.870657
#
# Completed comparison: Black Girls Code vs Beginner's Code Zone
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 3895    know  5.467714
# 336       im  4.713482
# 2943      go  4.282099
# 1773    make  4.123132
# 3438  people  3.960837
# 803    thing  3.945425
# 3472    code  3.256428
# 786    block  3.223778
# 5032   black  3.203385
# 2268   would  3.199068
#
# Top 10 words distinctive to Beginner's Code Zone:
#           word    z_score
# 4840      list -16.657387
# 2032      next -15.725939
# 1661  previous -14.736002
# 3657      data -13.902835
# 4788   current -13.225987
# 3907      head -12.755032
# 746      value -11.361798
# 2115       new -11.356894
# 3040     equal -10.835462
# 3599  computer  -9.965872
#
# Completed comparison: Black Girls Code vs Coding Workshops for Kids - Online Coding Courses for Kids and Parents
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4007    know  7.671665
# 1059  really  5.766895
# 5064   think  5.612919
# 3543  people  5.465331
# 442     also  4.647941
# 3796     add  4.595509
# 3481       u  4.392641
# 96      dont  4.215848
# 2339   would  4.114295
# 5181   black  3.882570
#
# Top 10 words distinctive to Coding Workshops for Kids - Online Coding Courses for Kids and Parents:
#           word    z_score
# 1369     click -19.038618
# 2539    sprite -13.658160
# 4599   scratch -13.275676
# 805      block -12.739464
# 1220       let -10.888206
# 4635      tool -10.797802
# 2297  backdrop -10.777986
# 1307      line -10.240564
# 2396      onto  -9.166215
# 3794       cat  -9.095571
#
# Completed comparison: Black Girls Code vs Computer World Kids
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 3771    know  0.605080
# 2425    want  0.585198
# 2853      go  0.553326
# 1007  really  0.548741
# 1155     let  0.548741
# 4072     get  0.542071
# 1724    make  0.542071
# 4769   think  0.541442
# 3334  people  0.534925
# 3284   thats  0.532884
#
# Top 10 words distinctive to Computer World Kids:
#            word    z_score
# 2839     moving -24.983881
# 3303  sometimes -17.954309
# 2210        ill -12.869635
# 2826      there -12.286630
# 1098       time -11.367017
# 1705     enough -10.874122
# 1366       else  -9.961789
# 301        turn  -9.950038
# 2373       used  -9.862021
# 2058        ive  -8.626836
#
# Completed comparison: Black Girls Code vs Girls Will Code
#
# Top 10 words distinctive to Black Girls Code:
#         word   z_score
# 4023    know  7.679692
# 1059  really  6.293318
# 5088   think  6.044717
# 4837   youre  5.406908
# 3560  people  5.365945
# 5210   black  5.104466
# 4765     lot  4.300665
# 4435    work  4.221171
# 4729    girl  4.023867
# 4407    take  3.869543
#
# Top 10 words distinctive to Girls Will Code:
#           word    z_score
# 356     player -11.780041
# 4289  variable -11.637391
# 79        move -11.572048
# 2554    sprite -10.138678
# 2585      want  -9.944231
# 4091       say  -9.726412
# 637       name  -9.409849
# 2788       put  -8.971564
# 4638      ball  -8.966791
# 331         im  -8.583675
#
# Completed comparison: Black Girls Code vs Coding Kids
#
# Top 10 words distinctive to Black Girls Code:
#         word    z_score
# 1185  really  10.752467
# 3960  people   9.149489
# 5296     lot   8.438351
# 5784   black   8.374574
# 3689   thank   7.547176
# 588     love   6.690749
# 523   create   6.656306
# 5010   level   6.606705
# 4348   video   6.400445
# 3325    come   5.998307
#
# Top 10 words distinctive to Coding Kids:
#            word    z_score
# 5783        see -13.626833
# 2476     screen -13.237022
# 5568  something -11.947626
# 4163      shape -11.770576
# 1982       loop -11.725688
# 1576       file -11.712790
# 1471       line -11.710804
# 4288       type -11.481186
# 4545        say -11.384387
# 2157     number -11.354143
#
# Completed comparison: Black Girls Code vs Tech With Tim
#
# Top 10 words distinctive to Black Girls Code:
#               word    z_score
# 13976        black  39.690226
# 5202          love  30.849111
# 10130        block  27.343307
# 7930        career  26.302145
# 2223           art  26.072580
# 12580       people  25.977376
# 9459     community  25.648953
# 7619         thank  24.864378
# 14205  opportunity  22.357335
# 6933        sprite  22.069698
#
# Top 10 words distinctive to Tech With Tim:
#          word    z_score
# 8293      say -18.244699
# 16856   equal -13.726224
# 316        im -12.328528
# 7766     kind -12.316973
# 11534    need -11.901034
# 10529     let -11.898726
# 9954      run  -9.976245
# 17503    type  -9.904972
# 10672    file  -9.212410
# 915    inside  -9.190702
#
# Completed comparison: Black Girls Code vs Jenny's Lectures CS IT
#
# Top 10 words distinctive to Black Girls Code:
#          word    z_score
# 1241   really  33.913867
# 4009   people  31.024445
# 2105     make  28.023439
# 11281   youre  27.595474
# 11081    game  26.409168
# 7516     look  25.000746
# 5339      lot  23.487330
# 5679    think  23.074395
# 6507     love  22.874639
# 9241    there  22.843089
#
# Top 10 words distinctive to Jenny's Lectures CS IT:
#            word    z_score
# 10899       one -18.593401
# 8519      would -17.126359
# 8781   function -15.645459
# 5804        see -15.172373
# 4437      write -14.442467
# 904       value -13.953797
# 532        also -13.749090
# 1181        two -13.192197
# 2384       plus -12.928932
# 8083     number -12.652817
#
# Saved combined comparisons file
# Analysis complete!
